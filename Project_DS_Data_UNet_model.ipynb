# %%
#https://drive.google.com/drive/folders/144oOPmokoCcWelG7bO172CTR0MTcm7ku?usp=sharing

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/Updated_Random_series/Random_series'
# Out:
# Random_series_001  Random_series_041  Random_series_081  Random_series_121  Random_series_161
# Random_series_002  Random_series_042  Random_series_082  Random_series_122  Random_series_162
# Random_series_003  Random_series_043  Random_series_083  Random_series_123  Random_series_163
# Random_series_004  Random_series_044  Random_series_084  Random_series_124  Random_series_164
# Random_series_005  Random_series_045  Random_series_085  Random_series_125  Random_series_165
# Random_series_006  Random_series_046  Random_series_086  Random_series_126  Random_series_166
# Random_series_007  Random_series_047  Random_series_087  Random_series_127  Random_series_167
# Random_series_008  Random_series_048  Random_series_088  Random_series_128  Random_series_168
# Random_series_009  Random_series_049  Random_series_089  Random_series_129  Random_series_169
# Random_series_010  Random_series_050  Random_series_090  Random_series_130  Random_series_170
# Random_series_011  Random_series_051  Random_series_091  Random_series_131  Random_series_171
# Random_series_012  Random_series_052  Random_series_092  Random_series_132  Random_series_172
# Random_series_013  Random_series_053  Random_series_093  Random_series_133  Random_series_173
# Random_series_014  Random_series_054  Random_series_094  Random_series_134  Random_series_174
# Random_series_015  Random_series_055  Random_series_095  Random_series_135  Random_series_175
# Random_series_016  Random_series_056  Random_series_096  Random_series_136  Random_series_176
# Random_series_017  Random_series_057  Random_series_097  Random_series_137  Random_series_177
# Random_series_018  Random_series_058  Random_series_098  Random_series_138  Random_series_178
# Random_series_019  Random_series_059  Random_series_099  Random_series_139  Random_series_179
# Random_series_020  Random_series_060  Random_series_100  Random_series_140  Random_series_180
# Random_series_021  Random_series_061  Random_series_101  Random_series_141  Random_series_181
# Random_series_022  Random_series_062  Random_series_102  Random_series_142  Random_series_182
# Random_series_023  Random_series_063  Random_series_103  Random_series_143  Random_series_183
# Random_series_024  Random_series_064  Random_series_104  Random_series_144  Random_series_184
# Random_series_025  Random_series_065  Random_series_105  Random_series_145  Random_series_185
# Random_series_026  Random_series_066  Random_series_106  Random_series_146  Random_series_186
# Random_series_027  Random_series_067  Random_series_107  Random_series_147  Random_series_187
# Random_series_028  Random_series_068  Random_series_108  Random_series_148  Random_series_188
# Random_series_029  Random_series_069  Random_series_109  Random_series_149  Random_series_189
# Random_series_030  Random_series_070  Random_series_110  Random_series_150  Random_series_190
# Random_series_031  Random_series_071  Random_series_111  Random_series_151  Random_series_191
# Random_series_032  Random_series_072  Random_series_112  Random_series_152  Random_series_192
# Random_series_033  Random_series_073  Random_series_113  Random_series_153  Random_series_193
# Random_series_034  Random_series_074  Random_series_114  Random_series_154  Random_series_194
# Random_series_035  Random_series_075  Random_series_115  Random_series_155  Random_series_195
# Random_series_036  Random_series_076  Random_series_116  Random_series_156  Random_series_196
# Random_series_037  Random_series_077  Random_series_117  Random_series_157  Random_series_197
# Random_series_038  Random_series_078  Random_series_118  Random_series_158  Random_series_198
# Random_series_039  Random_series_079  Random_series_119  Random_series_159  Random_series_199
# Random_series_040  Random_series_080  Random_series_120  Random_series_160  Random_series_200

# %%
import os
import fnmatch
import pandas as pd
import json

# %%
path_list = []
for root, dirs, files in os.walk('/content/drive/My Drive/Updated_Random_series/Random_series'):
    # print(root)
    if len(root)>2:
        path_list.append(root)

path_list = sorted(path_list[1:])
path_list
# Out:
# ['/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_001',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_002',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_003',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_004',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_005',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_006',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_007',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_008',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_009',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_010',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_011',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_012',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_013',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_014',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_015',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_016',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_017',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_018',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_019',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_020',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_021',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_022',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_023',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_024',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_025',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_026',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_027',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_028',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_029',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_030',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_031',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_032',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_033',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_034',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_035',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_036',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_037',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_038',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_039',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_040',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_041',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_042',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_043',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_044',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_045',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_046',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_047',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_048',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_049',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_050',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_051',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_052',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_053',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_054',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_055',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_056',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_057',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_058',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_059',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_060',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_061',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_062',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_063',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_064',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_065',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_066',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_067',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_068',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_069',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_070',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_071',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_072',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_073',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_074',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_075',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_076',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_077',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_078',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_079',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_080',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_081',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_082',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_083',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_084',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_085',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_086',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_087',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_088',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_089',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_090',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_091',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_092',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_093',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_094',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_095',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_096',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_097',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_098',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_099',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_100',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_101',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_102',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_103',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_104',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_105',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_106',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_107',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_108',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_109',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_110',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_111',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_112',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_113',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_114',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_115',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_116',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_117',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_118',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_119',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_120',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_121',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_122',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_123',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_124',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_125',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_126',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_127',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_128',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_129',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_130',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_131',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_132',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_133',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_134',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_135',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_136',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_137',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_138',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_139',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_140',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_141',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_142',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_143',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_144',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_145',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_146',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_147',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_148',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_149',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_150',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_151',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_152',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_153',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_154',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_155',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_156',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_157',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_158',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_159',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_160',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_161',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_162',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_163',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_164',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_165',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_166',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_167',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_168',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_169',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_170',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_171',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_172',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_173',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_174',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_175',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_176',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_177',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_178',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_179',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_180',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_181',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_182',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_183',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_184',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_185',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_186',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_187',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_188',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_189',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_190',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_191',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_192',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_193',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_194',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_195',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_196',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_197',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_198',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_199',
#  '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_200']

# %%
import os
import fnmatch
import pandas as pd
import json
#########################################
### Data Preprocessing (Local setup)
#######################################
# def delete_non_filtered_tif_files(folder_path):
#     # Deletes all files starting with 'Non-Filtered' and with the '.tif' extension
#     # from the specified folder and its subfolders.
#     if not os.path.isdir(folder_path):
#         print(f"Error: The folder '{folder_path}' does not exist.")
#         return

#     # Traverse the folder and its subfolders
#     for root, dirs, files in os.walk(folder_path):
#         for filename in files:
#             # Check if the file matches the naming criteria
#             if fnmatch.fnmatch(filename, 'Non-Filtered*.tif'):
#                 file_path = os.path.join(root, filename)
#                 try:
#                     os.remove(file_path)
#                     print(f"Deleted: {file_path}")
#                 except Exception as e:
#                     print(f"Error deleting file '{file_path}': {e}")

# if __name__ == "__main__":

#     target_folder = './'
#     delete_non_filtered_tif_files(target_folder)

# path_list = []
# for root, dirs, files in os.walk('./'):
#     # print(root)
#     if len(root)>2:
#         path_list.append(root)

# print(path_list)

# for path in path_list:
#     # path = './Random_series_001'
#     data = pd.read_csv(f'{path}/image_data.csv')
#     df = pd.DataFrame(data)
#     df = df.drop(['BaS', 'Sn2BaS3', 'SnS', 'BaS_thickness_cm', 'Sn2BaS3_thickness_cm', 'SnS_thickness_cm'], axis=1)

#     with open(f'{path}/settings.json', 'r') as f:
#         settings = json.load(f)

#     boundary1 = settings['boundaries'][1]
#     boundary2 = settings['boundaries'][2]

#     df['target_1'] = df['F'].apply(lambda x: 1 if x < boundary1 else 0)
#     df['target_2'] = df['F'].apply(lambda x: 1 if x >= boundary1 and x <= boundary2 else 0)
#     df['target_3'] = df['F'].apply(lambda x: 1 if x > boundary2 else 0)

#     df.to_csv(f'{path}/image_data_1.csv', index=False)

# print(df.head())
# print(settings['boundaries'])


###########################################
## TRAIN - VAL - TEST (Local setup)
###########################################

# path_list = []
# for root, dirs, files in os.walk('./'):
#     # print(root)
#     if len(root)>2:
#         path_list.append(root)


train_directories = path_list[:100]
val_directories = path_list[100:150]
test_directories = path_list[150:]

print(train_directories)
print(val_directories)
print(test_directories)

combined_data = pd.DataFrame()
for directory in train_directories:
    file_path = os.path.join(directory, 'image_data_1.csv')

    if os.path.exists(file_path):
        df = pd.read_csv(file_path)

        combined_data = pd.concat([combined_data, df], ignore_index=True)
    else:
        print(f"File not found: {file_path}")

combined_data.to_csv('train_data.csv', index=False)

print("Data combined successfully into 'train_data.csv'.")

combined_data = pd.DataFrame()
for directory in val_directories:
    file_path = os.path.join(directory, 'image_data_1.csv')

    if os.path.exists(file_path):
        df = pd.read_csv(file_path)

        combined_data = pd.concat([combined_data, df], ignore_index=True)
    else:
        print(f"File not found: {file_path}")

combined_data.to_csv('val_data.csv', index=False)

print("Data combined successfully into 'val_data.csv'.")

combined_data = pd.DataFrame()
for directory in test_directories:
    file_path = os.path.join(directory, 'image_data_1.csv')

    if os.path.exists(file_path):
        df = pd.read_csv(file_path)

        combined_data = pd.concat([combined_data, df], ignore_index=True)
    else:
        print(f"File not found: {file_path}")

combined_data.to_csv('test_data.csv', index=False)

print("Data combined successfully into 'test_data.csv'.")
# Out:
# ['/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_001', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_002', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_003', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_004', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_005', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_006', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_007', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_008', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_009', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_010', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_011', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_012', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_013', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_014', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_015', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_016', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_017', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_018', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_019', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_020', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_021', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_022', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_023', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_024', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_025', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_026', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_027', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_028', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_029', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_030', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_031', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_032', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_033', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_034', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_035', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_036', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_037', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_038', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_039', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_040', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_041', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_042', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_043', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_044', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_045', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_046', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_047', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_048', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_049', '/content/drive/My Drive/Updat ...
# ['/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_101', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_102', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_103', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_104', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_105', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_106', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_107', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_108', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_109', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_110', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_111', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_112', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_113', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_114', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_115', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_116', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_117', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_118', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_119', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_120', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_121', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_122', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_123', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_124', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_125', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_126', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_127', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_128', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_129', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_130', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_131', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_132', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_133', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_134', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_135', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_136', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_137', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_138', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_139', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_140', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_141', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_142', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_143', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_144', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_145', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_146', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_147', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_148', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_149', '/content/drive/My Drive/Updat ...
# ['/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_151', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_152', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_153', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_154', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_155', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_156', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_157', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_158', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_159', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_160', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_161', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_162', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_163', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_164', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_165', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_166', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_167', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_168', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_169', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_170', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_171', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_172', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_173', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_174', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_175', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_176', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_177', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_178', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_179', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_180', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_181', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_182', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_183', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_184', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_185', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_186', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_187', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_188', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_189', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_190', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_191', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_192', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_193', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_194', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_195', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_196', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_197', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_198', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_199', '/content/drive/My Drive/Updat ...
# Data combined successfully into 'train_data.csv'.
# Data combined successfully into 'val_data.csv'.
# Data combined successfully into 'test_data.csv'.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression

# %%
train_data = pd.read_csv('train_data.csv')
val_data = pd.read_csv('val_data.csv')
test_data = pd.read_csv('test_data.csv')

train_data.head()
# Out:
#       x     y            Sn            Ba         F  target
# 0 -2.49 -0.49  1.926823e-07  2.864439e-07  0.402154       1
# 1 -2.49 -0.44  1.920718e-07  2.853302e-07  0.402327       1
# 2 -2.49 -0.39  1.914566e-07  2.842045e-07  0.402506       1
# 3 -2.49 -0.34  1.908368e-07  2.830671e-07  0.402691       1
# 4 -2.49 -0.29  1.902124e-07  2.819184e-07  0.402881       1

# %%
train_data.shape
# Out:
# (809200, 6)

# %%
test_data.shape
# Out:
# (404600, 6)

# %%
# val_data.head(), test_data.head()

# %%
train_data['log_Sn'] = np.log(train_data['Sn'] * 1e7  + 1)
train_data['log_Ba'] = np.log(train_data['Ba'] * 1e7  + 1)
# train_data['log_F'] = np.log(train_data['F'] + 1)

val_data['log_Sn'] = np.log(val_data['Sn'] * 1e7  + 1)
val_data['log_Ba'] = np.log(val_data['Ba'] * 1e7  + 1)
# val_data['log_F'] = np.log(val_data['F'] + 1)

test_data['log_Sn'] = np.log(test_data['Sn'] * 1e7  + 1)
test_data['log_Ba'] = np.log(test_data['Ba'] * 1e7  + 1)
# test_data['log_F'] = np.log(test_data['F'] + 1)

# %%
train_data.head()
# Out:
#       x     y            Sn            Ba         F  target    log_Sn  \
# 0 -2.49 -0.49  1.926823e-07  2.864439e-07  0.402154       1  1.073917
# 1 -2.49 -0.44  1.920718e-07  2.853302e-07  0.402327       1  1.071830
# 2 -2.49 -0.39  1.914566e-07  2.842045e-07  0.402506       1  1.069721
# 3 -2.49 -0.34  1.908368e-07  2.830671e-07  0.402691       1  1.067592
# 4 -2.49 -0.29  1.902124e-07  2.819184e-07  0.402881       1  1.065443
#
#      log_Ba
# 0  1.351817
# 1  1.348930
# 2  1.346005
# 3  1.343040
# 4  1.340037

# %%
# scaler = MinMaxScaler()

# train_data[['log_Sn', 'log_Ba']] = scaler.fit_transform(train_data[['log_Sn', 'log_Ba']])
# val_data[['log_Sn', 'log_Ba']] = scaler.fit_transform(val_data[['log_Sn', 'log_Ba']])
# test_data[['log_Sn', 'log_Ba']] = scaler.fit_transform(test_data[['log_Sn', 'log_Ba']])

# %%
# train_data.head()

# %%
X_train = train_data.drop(['Sn', 'Ba'], axis=1)
y_train = train_data[['target']]
X_val = val_data.drop(['Sn', 'Ba'], axis=1)
y_val = val_data[['target']]
X_test = test_data.drop(['Sn', 'Ba'], axis=1)
y_test = test_data[['target']]

# %%
X_train.head(), y_train.head()
# Out:
# (      x     y         F  target    log_Sn    log_Ba
#  0 -2.49 -0.49  0.402154       1  1.073917  1.351817
#  1 -2.49 -0.44  0.402327       1  1.071830  1.348930
#  2 -2.49 -0.39  0.402506       1  1.069721  1.346005
#  3 -2.49 -0.34  0.402691       1  1.067592  1.343040
#  4 -2.49 -0.29  0.402881       1  1.065443  1.340037,
#     target
#  0       1
#  1       1
#  2       1
#  3       1
#  4       1)

# %%
print(f"Training set size: {X_train.shape}")
print(f"Validation set size: {X_val.shape}")
print(f"Test set size: {X_test.shape}")
# Out:
# Training set size: (809200, 6)
# Validation set size: (404600, 6)
# Test set size: (404600, 6)

# %%
from sklearn.multioutput import MultiOutputClassifier
clf = MultiOutputClassifier(LogisticRegression(multi_class='ovr'))

clf.fit(X_train, y_train)

y_val_pred = clf.predict(X_val)

val_accuracy = accuracy_score(y_val, y_val_pred)
print(f"Validation Accuracy: {val_accuracy}")

y_test_pred = clf.predict(X_test)

test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Validation Accuracy: 1.0
# Test Accuracy: 1.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from PIL import Image

def plot_targets_on_image(df):
    # Determine the range of coordinates
    x_min, x_max = df['x'].min(), df['x'].max()
    y_min, y_max = df['y'].min(), df['y'].max()
    # print(x_min, x_max, y_min, y_max)

    # Create a blank white image based on the coordinate range
    img_width = int(x_max - x_min)
    img_height = int(y_max - y_min)
    img = Image.new('RGB', (img_width, img_height), 'white')
    print(img_width, img_height)
    # Create a figure and axis
    fig, ax = plt.subplots()

    # Display the blank image
    ax.imshow(img, extent=[x_min, x_max, y_min, y_max], aspect='equal')

    # Plot points based on target values
    colors = {1: 'lightblue', 2: 'plum', 3: 'tomato'}

    # Plot each unique coordinate for each target
    for target in colors.keys():
        target_points = df[df['target'] == target]

        # Use the coordinates to plot the points on the image
        ax.scatter(target_points['x'], target_points['y'],
                   color=colors[target],
                   label=f'Target {target}',
                   s=10,
                   alpha=0.5)

    # Set the axis limits to match the coordinate range
    ax.set_xlim([x_min, x_max])
    ax.set_ylim([y_min, y_max])

    # Encode the target labels
    le = LabelEncoder()
    df['target_encoded'] = le.fit_transform(df['target'])

    # Fit logistic regression model
    X = df[['x', 'y', 'log_Sn', 'log_Ba']]
    y = df['target_encoded']
    model = LogisticRegression(multi_class='auto')
    model.fit(X, y)

    # Calculate placeholder values for log_Sn and log_Ba
    log_Sn_mean = df['log_Sn'].mean()
    log_Ba_mean = df['log_Ba'].mean()

    # Create a mesh to plot the decision boundaries
    xx, yy = np.meshgrid(np.linspace(x_min - 1, x_max + 1, 100), np.linspace(y_min - 1, y_max + 1, 100))

    # Ensure xx and yy are DataFrames with the appropriate column names
    grid_points = pd.DataFrame(np.c_[xx.ravel(), yy.ravel(),
                                     np.full(xx.ravel().shape, log_Sn_mean),
                                     np.full(xx.ravel().shape, log_Ba_mean)],
                               columns=['x', 'y', 'log_Sn', 'log_Ba'])
    Z = model.predict(grid_points)
    Z = Z.reshape(xx.shape)

    # Plot decision boundaries
    ax.contour(xx, yy, Z, levels=[0.5, 1.5], colors=['darkgreen', 'darkblue'], linestyles=['-', '-'])

    # Add labels and legend
    ax.set_title('"True" Decision Boundaries')
    ax.set_xlabel('X Coordinate')
    ax.set_ylabel('Y Coordinate')
    ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

    # Show the plot
    plt.show()

# %%
def get_image_data(image_index, test_data):
    start_row = image_index * 8092
    end_row = start_row + 8092
    return test_data.iloc[start_row:end_row]

# Example: Get data for the first image (image_index = 0)
first_image_data = get_image_data(0, X_train)

plot_targets_on_image(first_image_data)
# Out:
# 4 4

# %%
# import seaborn as sns
# sns.pairplot(first_image_data, vars=['x', 'y', 'log_Sn', 'log_Ba'], hue='target', palette=['darkgreen', 'darkgreen'])
# plt.show()

# %% [markdown]
# # Enhanced Images

# %%
# import matplotlib.pyplot as plt
# from PIL import Image, ImageEnhance

# original_image_path = './Filtered_T_Image.tif'
# original_image = Image.open(original_image_path)

# def enhance_contrast_and_brightness(img, contrast_factor=1.5, brightness_factor=1.2):
#     brightness_enhancer = ImageEnhance.Brightness(img)
#     brightened_img = brightness_enhancer.enhance(brightness_factor)

#     contrast_enhancer = ImageEnhance.Contrast(brightened_img)
#     enhanced_img = contrast_enhancer.enhance(contrast_factor)

#     return enhanced_img

# enhanced_image = enhance_contrast_and_brightness(original_image, contrast_factor=3.0, brightness_factor=2.5)


# plt.figure(figsize=(12, 6))

# plt.subplot(1, 2, 1)
# plt.imshow(original_image, cmap='gray')
# plt.title('Original Image')

# plt.subplot(1, 2, 2)
# plt.imshow(enhanced_image, cmap='gray')
# plt.title('Enhanced Image')

# plt.show()

# %% [markdown]
# #UNet Model

# %%
train_directories = path_list[:100]
val_directories = path_list[100:150]
test_directories = path_list[150:]

print(train_directories)
print(val_directories)
print(test_directories)
# Out:
# ['/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_001', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_002', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_003', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_004', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_005', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_006', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_007', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_008', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_009', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_010', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_011', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_012', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_013', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_014', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_015', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_016', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_017', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_018', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_019', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_020', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_021', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_022', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_023', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_024', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_025', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_026', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_027', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_028', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_029', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_030', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_031', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_032', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_033', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_034', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_035', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_036', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_037', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_038', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_039', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_040', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_041', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_042', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_043', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_044', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_045', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_046', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_047', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_048', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_049', '/content/drive/My Drive/Updat ...
# ['/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_101', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_102', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_103', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_104', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_105', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_106', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_107', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_108', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_109', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_110', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_111', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_112', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_113', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_114', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_115', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_116', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_117', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_118', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_119', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_120', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_121', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_122', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_123', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_124', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_125', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_126', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_127', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_128', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_129', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_130', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_131', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_132', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_133', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_134', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_135', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_136', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_137', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_138', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_139', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_140', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_141', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_142', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_143', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_144', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_145', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_146', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_147', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_148', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_149', '/content/drive/My Drive/Updat ...
# ['/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_151', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_152', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_153', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_154', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_155', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_156', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_157', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_158', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_159', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_160', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_161', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_162', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_163', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_164', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_165', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_166', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_167', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_168', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_169', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_170', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_171', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_172', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_173', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_174', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_175', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_176', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_177', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_178', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_179', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_180', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_181', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_182', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_183', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_184', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_185', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_186', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_187', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_188', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_189', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_190', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_191', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_192', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_193', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_194', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_195', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_196', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_197', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_198', '/content/drive/My Drive/Updated_Random_series/Random_series/Random_series_199', '/content/drive/My Drive/Updat ...

# %%
print(len(train_directories))
print(len(val_directories))
print(len(test_directories))
# Out:
# 100
# 50
# 50

# %%
import cv2
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.utils import to_categorical, Sequence
import matplotlib.pyplot as plt

# %%
# for directory in train_directories:
#     file_path = os.path.join(directory, 'image_data_1.csv')

#     if os.path.exists(file_path):
#         df = pd.read_csv(file_path)

#         combined_data = pd.concat([combined_data, df], ignore_index=True)
#     else:
#         print(f"File not found: {file_path}")

# combined_data.to_csv('train_data.csv', index=False)


# Define global parameters
point_radius = 5
input_channels = 8

# Crop images
def combine_data_and_images(image_R, image_T):
    left = 135
    upper = 13
    right = 740
    lower = 618
    # Use numpy slicing to crop
    cropped_image_R = image_R[upper:lower, left:right]
    cropped_image_T = image_T[upper:lower, left:right]
    return cropped_image_R, cropped_image_T

# Get all data paths in the dataset
def get_data_paths(data_dir):
    data_paths = []
    for directory in data_dir:
        # Convert filenames to lowercase for easier matching
        # files_lower = [f.lower() for f in files]
        required_files = ['Filtered_R_Image.tif', 'Filtered_T_Image.tif', 'image_data_1.csv']
        for i in required_files:
            file_path = os.path.join(directory, i)
            if os.path.exists(file_path):
                data_paths.append(directory)
                # break
    return data_paths

# Normalize and scale x and y to the range 0-605
def transform_coordinates(data):
    # Find the minimum and maximum values of x and y
    x_min, x_max = data['x'].min(), data['x'].max()
    y_min, y_max = data['y'].min(), data['y'].max()

    # Normalize and scale to 0-605
    data['x_new'] = ((data['x'] - x_min) / (x_max - x_min)) * 605
    data['y_new'] = ((data['y'] - y_min) / (y_max - y_min)) * 605

    return data[['x_new', 'y_new']]

# Collect all categories in the training set
def collect_train_categories(train_paths):
    categories = set()
    for path in train_paths:
        csv_path = os.path.join(path, 'image_data_1.csv')
        if os.path.exists(csv_path):
            data = pd.read_csv(csv_path)
            transformed = transform_coordinates(data)  # Apply coordinate transformation
            data[['x_new', 'y_new']] = transformed
            categories.update(data['target'].unique())
        else:
            print(f"Warning: File not found {csv_path}")
    return sorted(list(categories))

# Get training, validation, and test data paths
train_paths = get_data_paths(train_directories)
val_paths = get_data_paths(val_directories)
test_paths = get_data_paths(test_directories)

# Check if the training set is empty
if not train_paths:
    raise ValueError("No training data found. Please check the training data directory and filenames.")
else:
    print(f"Found {len(train_paths)} training samples.")

if not val_paths:
    print("No validation data found. Please check the validation data directory and filenames.")
else:
    print(f"Found {len(val_paths)} validation samples.")

if not test_paths:
    print("No test data found. Please check the test data directory and filenames.")
else:
    print(f"Found {len(test_paths)} test samples.")

# Collect all categories in the training set
train_categories = collect_train_categories(train_paths)
print(f"Categories in the training set: {train_categories}")
# Out:
# Found 300 training samples.
# Found 150 validation samples.
# Found 150 test samples.
# Categories in the training set: [1, 2, 3]

# %%
# Fit OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoder.fit(np.array(train_categories).reshape(-1, 1))
num_classes = len(encoder.categories_[0]) + 1  # Add 1 to include background
print(f"Number of classes (including background): {num_classes}")
# Out:
# Number of classes (including background): 4

# %%
# Define data generator for batch loading and preprocessing
class DataGenerator(Sequence):
    def __init__(self, list_IDs, batch_size=1, shuffle=True, encoder=None, num_classes=None):
        """
        Initialize data generator.

        Parameters:
            list_IDs (list): List of data subfolder paths.
            batch_size (int): Number of samples per batch.
            shuffle (bool): Whether to shuffle data after each epoch.
            encoder (OneHotEncoder): Pre-fitted OneHotEncoder.
            num_classes (int): Number of classes (including background).
        """
        self.list_IDs = list_IDs
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.encoder = encoder
        self.num_classes = num_classes
        self.indexes = np.arange(len(self.list_IDs))
        self.on_epoch_end()

    # Return number of steps per epoch
    def __len__(self):
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    # Generate one batch of data
    def __getitem__(self, index):
        # Generate indices of the current batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # Get IDs for the current batch
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        # Generate data
        X, y = self.__data_generation(list_IDs_temp)
        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

    # Generate batch data
    def __data_generation(self, list_IDs_temp):
        # Initialize
        X_batch = []
        y_batch = []
        for ID in list_IDs_temp:
            # Load and preprocess data
            X, y = load_and_preprocess_data(ID, self.encoder, self.num_classes)
            X_batch.append(X)
            y_batch.append(y)
        # Convert to arrays
        X_batch = np.array(X_batch)
        y_batch = np.array(y_batch)
        return X_batch, y_batch

# Load images and label data, and preprocess
def load_and_preprocess_data(data_path, encoder, num_classes):
    image_path_R = os.path.join(data_path, 'Filtered_R_Image.tif')
    image_path_T = os.path.join(data_path, 'Filtered_T_Image.tif')
    csv_path = os.path.join(data_path, 'image_data_1.csv')

    # Load RGB images
    image_R = cv2.imread(image_path_R, cv2.IMREAD_COLOR)
    if image_R is None:
        raise ValueError(f"Cannot read image file: {image_path_R}")
    image_R = cv2.cvtColor(image_R, cv2.COLOR_BGR2RGB)

    image_T = cv2.imread(image_path_T, cv2.IMREAD_COLOR)
    if image_T is None:
        raise ValueError(f"Cannot read image file: {image_path_T}")
    image_T = cv2.cvtColor(image_T, cv2.COLOR_BGR2RGB)

    # Crop both images
    image_R, image_T = combine_data_and_images(image_R, image_T)

    # Load CSV file
    if not os.path.exists(csv_path):
        raise ValueError(f"File not found: {csv_path}")
    data = pd.read_csv(csv_path)

    # Apply coordinate transformation
    transformed = transform_coordinates(data)
    data[['x_new', 'y_new']] = transformed

    # Get image dimensions
    height, width, _ = image_R.shape

    # Extract central circular region
    center_x, center_y = width // 2, height // 2
    radius = 605 // 2

    Y, X_grid = np.ogrid[:height, :width]
    dist_from_center = np.sqrt((X_grid - center_x)**2 + (Y - center_y)**2)
    mask = dist_from_center <= radius

    # Apply mask to each channel
    masked_image_R = np.zeros_like(image_R)
    masked_image_R[mask] = image_R[mask]

    masked_image_T = np.zeros_like(image_T)
    masked_image_T[mask] = image_T[mask]

    # Process numerical variables 'Sn' and 'Ba'
    # Create two single-channel images, initialized to 0
    sn_image = np.zeros((height, width), dtype=np.float32)
    ba_image = np.zeros((height, width), dtype=np.float32)

    # Get data coordinate range
    x_min, x_max = data['x'].min(), data['x'].max()
    y_min, y_max = data['y'].min(), data['y'].max()

    # Map data coordinates to image pixel coordinates
    data['x_pixel'] = data['x_new'].astype(int)
    data['y_pixel'] = data['y_new'].astype(int)
    data['x_pixel'] = data['x_pixel'].clip(0, width - 1)
    data['y_pixel'] = data['y_pixel'].clip(0, height - 1)

    # Fill 'Sn' and 'Ba' images
    for idx, row in data.iterrows():
        x = int(row['x_pixel'])  # Ensure x is integer
        y = int(row['y_pixel'])  # Ensure y is integer
        sn_image[y, x] = row['Sn']
        ba_image[y, x] = row['Ba']

    # Apply mask to 'Sn' and 'Ba' images
    masked_sn = np.zeros_like(sn_image)
    masked_sn[mask] = sn_image[mask]

    masked_ba = np.zeros_like(ba_image)
    masked_ba[mask] = ba_image[mask]

    # Normalize 'Sn' and 'Ba' images to [0, 255]
    max_sn = np.max(masked_sn)
    max_ba = np.max(masked_ba)
    masked_sn = (masked_sn / max_sn * 255).astype(np.uint8) if max_sn != 0 else masked_sn.astype(np.uint8)
    masked_ba = (masked_ba / max_ba * 255).astype(np.uint8) if max_ba != 0 else masked_ba.astype(np.uint8)

    # Adjust image size to multiples of 16
    new_height = (height // 16) * 16
    new_width = (width // 16) * 16
    masked_image_R = masked_image_R[:new_height, :new_width, :]
    masked_image_T = masked_image_T[:new_height, :new_width, :]
    masked_sn = masked_sn[:new_height, :new_width]
    masked_ba = masked_ba[:new_height, :new_width]
    height, width, _ = masked_image_R.shape

    # Add 'Sn' and 'Ba' as additional channels
    sn_channel = np.expand_dims(masked_sn, axis=-1)
    ba_channel = np.expand_dims(masked_ba, axis=-1)
    input_image = np.concatenate([masked_image_R, masked_image_T, sn_channel, ba_channel], axis=-1)

    # Encode the 'Category' column
    categories_encoded = encoder.transform(data[['target']])

    # Create target mask
    target_mask = np.zeros((height, width), dtype=np.uint8)

    for idx, row in data.iterrows():
        x = int(row['x_pixel'])  # Ensure x is integer
        y = int(row['y_pixel'])  # Ensure y is integer
        category_index = int(np.argmax(categories_encoded[idx]) + 1)  # Add 1 to avoid background being 0
        cv2.circle(target_mask, (x, y), point_radius, category_index, -1)

    # One-Hot encode the target mask
    target_mask_one_hot = to_categorical(target_mask, num_classes=num_classes)

    return input_image, target_mask_one_hot

# Create training, validation, and test data generators
train_generator = DataGenerator(train_paths, batch_size=1, shuffle=True, encoder=encoder, num_classes=num_classes)
val_generator = DataGenerator(val_paths, batch_size=1, shuffle=False, encoder=encoder, num_classes=num_classes)
test_generator = DataGenerator(test_paths, batch_size=1, shuffle=False, encoder=encoder, num_classes=num_classes)

# %%
# Define UNet model
def unet_model(input_size, num_classes):
    inputs = layers.Input(input_size)

    # Downsampling part
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2,2), padding='same')(c1)

    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2,2), padding='same')(c2)

    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2,2), padding='same')(c3)

    c4 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D((2,2), padding='same')(c4)

    # Bottleneck
    c5 = layers.Conv2D(1024, (3,3), activation='relu', padding='same')(p4)
    c5 = layers.Conv2D(1024, (3,3), activation='relu', padding='same')(c5)

    # Upsampling part
    u6 = layers.UpSampling2D((2,2))(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(c6)

    u7 = layers.UpSampling2D((2,2))(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c7)

    u8 = layers.UpSampling2D((2,2))(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(u8)
    c8 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c8)

    u9 = layers.UpSampling2D((2,2))(c8)
    u9 = layers.concatenate([u9, c1])
    c9 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(u9)
    c9 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c9)

    outputs = layers.Conv2D(num_classes, (1,1), activation='softmax')(c9)

    model = models.Model(inputs=[inputs], outputs=[outputs])
    return model

# Create model
sample_X, sample_y = train_generator[0]
input_height, input_width, _ = sample_X.shape[1:]
input_size = (input_height, input_width, input_channels)

model = unet_model(input_size=input_size, num_classes=num_classes)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define learning rate scheduler
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Monitor validation loss
    factor=0.5,            # When the monitored metric stops improving, reduce learning rate by half
    patience=3,            # Number of epochs with no improvement before reducing learning rate
    min_lr=1e-6            # Minimum learning rate
)

# Add callbacks when training the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=15,
    callbacks=[reduce_lr]
)

model.save('unet_model.h5')
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3             │ (None, 592, 592, 8)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_57 (Conv2D)        │ (None, 592, 592, 64)   │          4,672 │ input_layer_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_58 (Conv2D)        │ (None, 592, 592, 64)   │         36,928 │ conv2d_57[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_12          │ (None, 296, 296, 64)   │              0 │ conv2d_58[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_59 (Conv2D)        │ (None, 296, 296, 128)  │         73,856 │ max_pooling2d_12[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_60 (Conv2D)        │ (None, 296, 296, 128)  │        147,584 │ conv2d_59[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_13          │ (None, 148, 148, 128)  │              0 │ conv2d_60[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_61 (Conv2D)        │ (None, 148, 148, 256)  │        295,168 │ max_pooling2d_13[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_62 (Conv2D)        │ (None, 148, 148, 256)  │        590,080 │ conv2d_61[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_14          │ (None, 74, 74, 256)    │              0 │ conv2d_62[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_63 (Conv2D)        │ (None, 74, 74, 512)    │      1,180,160 │ max_pooling2d_14[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_64 (Conv2D)        │ (None, 74, 74, 512)    │      2,359,808 │ conv2d_63[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_15          │ (None, 37, 37, 512)    │              0 │ conv2d_64[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_65 (Conv2D)        │ (None, 37, 37, 1024)   │      4,719,616 │ max_pooling2d_15[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_66 (Conv2D)        │ (None, 37, 37, 1024)   │      9,438,208 │ conv2d_65[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_12          │ (None, 74, 74, 1024)   │              0 │ conv2d_66[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_12            │ (None, 74, 74, 1536)   │              0 │ up_sampling2d_12[0][0… │
# │ (Concatenate)             │                        │                │ conv2d_64[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_67 (Conv2D)        │ (None, 74, 74, 512)    │      7,078,400 │ concatenate_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_68 (Conv2D)        │ (None, 74, 74, 512)    │      2,359,808 │ conv2d_67[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_13          │ (None, 148, 148, 512)  │              0 │ conv2d_68[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_13            │ (None, 148, 148, 768)  │              0 │ up_sampling2d_13[0][0… │
# │ (Concatenate)             │                        │                │ conv2d_62[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_69 (Conv2D)        │ (None, 148, 148, 256)  │      1,769,728 │ concatenate_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_70 (Conv2D)        │ (None, 148, 148, 256)  │        590,080 │ conv2d_69[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_14          │ (None, 296, 296, 256)  │              0 │ conv2d_70[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_14            │ (None, 296, 296, 384)  │              0 │ up_sampling2d_14[0][0… │
# │ (Concatenate)             │                        │                │ conv2d_60[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_71 (Conv2D)        │ (None, 296, 296, 128)  │        442,496 │ concatenate_14[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_72 (Conv2D)        │ (None, 296, 296, 128)  │        147,584 │ conv2d_71[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_15          │ (None, 592, 592, 128)  │              0 │ conv2d_72[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_15            │ (None, 592, 592, 192)  │              0 │ up_sampling2d_15[0][0… │
# │ (Concatenate)             │                        │                │ conv2d_58[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_73 (Conv2D)        │ (None, 592, 592, 64)   │        110,656 │ concatenate_15[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_74 (Conv2D)        │ (None, 592, 592, 64)   │         36,928 │ conv2d_73[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_75 (Conv2D)        │ (None, 592, 592, 4)    │            260 │ conv2d_74[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,382,020 (119.71 MB)
#  Trainable params: 31,382,020 (119.71 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 621s 2s/step - accuracy: 0.5694 - loss: 31.3261 - val_accuracy: 0.5719 - val_loss: 0.7723 - learning_rate: 0.0010
# Epoch 2/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 438s 1s/step - accuracy: 0.6711 - loss: 0.6611 - val_accuracy: 0.7160 - val_loss: 0.6005 - learning_rate: 0.0010
# Epoch 3/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 414s 1s/step - accuracy: 0.6981 - loss: 0.6481 - val_accuracy: 0.6790 - val_loss: 0.7383 - learning_rate: 0.0010
# Epoch 4/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - accuracy: 0.7229 - loss: 0.5900 - val_accuracy: 0.5024 - val_loss: 0.8924 - learning_rate: 0.0010
# Epoch 5/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 428s 1s/step - accuracy: 0.4440 - loss: 6.4042 - val_accuracy: 0.4184 - val_loss: 0.9615 - learning_rate: 0.0010
# Epoch 6/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 413s 1s/step - accuracy: 0.4849 - loss: 0.9293 - val_accuracy: 0.6174 - val_loss: 0.8736 - learning_rate: 5.0000e-04
# Epoch 7/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 443s 1s/step - accuracy: 0.5747 - loss: 0.9038 - val_accuracy: 0.6375 - val_loss: 0.8441 - learning_rate: 5.0000e-04
# Epoch 8/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - accuracy: 0.5868 - loss: 0.8550 - val_accuracy: 0.6589 - val_loss: 0.7977 - learning_rate: 5.0000e-04
# Epoch 9/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 447s 1s/step - accuracy: 0.6681 - loss: 0.7842 - val_accuracy: 0.6640 - val_loss: 0.7721 - learning_rate: 2.5000e-04
# Epoch 10/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 412s 1s/step - accuracy: 0.6854 - loss: 0.7237 - val_accuracy: 0.6966 - val_loss: 0.6424 - learning_rate: 2.5000e-04
# Epoch 11/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 441s 1s/step - accuracy: 0.6944 - loss: 0.5748 - val_accuracy: 0.7121 - val_loss: 0.5275 - learning_rate: 2.5000e-04
# Epoch 12/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.7280 - loss: 0.5127 - val_accuracy: 0.7635 - val_loss: 0.4957 - learning_rate: 2.5000e-04
# Epoch 13/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 443s 1s/step - accuracy: 0.7440 - loss: 0.4552 - val_accuracy: 0.7607 - val_loss: 0.4400 - learning_rate: 2.5000e-04
# Epoch 14/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 441s 1s/step - accuracy: 0.7306 - loss: 0.4968 - val_accuracy: 0.7504 - val_loss: 0.4427 - learning_rate: 2.5000e-04
# Epoch 15/15
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 408s 1s/step - accuracy: 0.7758 - loss: 0.4181 - val_accuracy: 0.8035 - val_loss: 0.3945 - learning_rate: 2.5000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Evaluate the model on the test set and calculate accuracy
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_acc}')

# Visualize results on the test set
def visualize_predictions(generator, model, num_samples=5):
    """
    Visualize model predictions on the test set.

    Parameters:
        generator (DataGenerator): Test set data generator.
        model (tf.keras.Model): Trained model.
        num_samples (int): Number of samples to visualize.
    """
    for i in range(num_samples):
        X, y_true = generator[i]
        y_pred = model.predict(X)

        # Get the input image, prediction, and true labels for a single sample
        input_image = X[0]  # Input image
        y_true = np.argmax(y_true[0], axis=-1)  # True labels
        y_pred = np.argmax(y_pred[0], axis=-1)  # Predicted labels

        # Visualize the results
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))
        axes[0].imshow(input_image[..., :3].astype(int))  # Show the first RGB image
        axes[0].set_title("Input Image (R)")
        axes[0].axis('off')

        axes[1].imshow(y_true, cmap="jet")  # True labels
        axes[1].set_title("True Labels")
        axes[1].axis('off')

        axes[2].imshow(y_pred, cmap="jet")  # Predicted labels
        axes[2].set_title("Predicted Labels")
        axes[2].axis('off')

        plt.show()

# Visualize some predictions on the test set
visualize_predictions(test_generator, model, num_samples=5)
# Out:
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.8048 - loss: 0.3690
# Test Loss: 0.3933546841144562, Test Accuracy: 0.8018919825553894
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 804ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %% [markdown]
# # Testing ( debugging )

# %%
# y_test.shape

# %%
# X_test[40176:40200], y_test[40176:40200], y_test_pred[40176:40200]

# %%
import cv2

# %%
def get_image_data(image_index, test_data):
    start_row = image_index * 8092
    end_row = start_row + 8092
    return test_data.iloc[start_row:end_row]

# Example: Get data for the first image (image_index = 0)
first_image_data = get_image_data(0, test_data)
print(first_image_data.shape)
first_image_data.head()

# %%
first_image_data.describe()

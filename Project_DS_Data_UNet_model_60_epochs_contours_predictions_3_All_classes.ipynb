# %%
#https://drive.google.com/drive/folders/144oOPmokoCcWelG7bO172CTR0MTcm7ku?usp=sharing

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive'
# Out:
#  170				'Group 27 (1)'
#  2017-21_Batch_Passbook_Copies	 IR-M2019-Assignment
# '5Km- Cross Country in 2017'	 ITWS_1_prototypes
# 'ASM Assignments UG3'		'jee main josaa.pdf'
# 'Bus Time table 2018.pdf'	'JoSAA 2017: Locked Choices of the Roll Number- 18419903.pdf'
#  cgm_svd_dataset		 Karthik
# 'Colab Notebooks'		'Play Books Notes'
#  DL_Assignment2			'Project Plan'
# 'FCOM S2019 Projects'		 Projects
#  FileHandler.ashx		 Random_series
#  Ganesh_Chaturthi_2017		'Roomies memories'
# 'Getting started.pdf'		 train.pdf
# 'Group 27'			'Untitled spreadsheet.gsheet'
#  Group-27			'yagnakarthik.v17@iiits.in 2023-02-02 21:28'

# %%
# !ls '/content/drive/My Drive/Random_series'
# Out:
# Random_series_001  Random_series_041  Random_series_081  Random_series_121  Random_series_161
# Random_series_002  Random_series_042  Random_series_082  Random_series_122  Random_series_162
# Random_series_003  Random_series_043  Random_series_083  Random_series_123  Random_series_163
# Random_series_004  Random_series_044  Random_series_084  Random_series_124  Random_series_164
# Random_series_005  Random_series_045  Random_series_085  Random_series_125  Random_series_165
# Random_series_006  Random_series_046  Random_series_086  Random_series_126  Random_series_166
# Random_series_007  Random_series_047  Random_series_087  Random_series_127  Random_series_167
# Random_series_008  Random_series_048  Random_series_088  Random_series_128  Random_series_168
# Random_series_009  Random_series_049  Random_series_089  Random_series_129  Random_series_169
# Random_series_010  Random_series_050  Random_series_090  Random_series_130  Random_series_170
# Random_series_011  Random_series_051  Random_series_091  Random_series_131  Random_series_171
# Random_series_012  Random_series_052  Random_series_092  Random_series_132  Random_series_172
# Random_series_013  Random_series_053  Random_series_093  Random_series_133  Random_series_173
# Random_series_014  Random_series_054  Random_series_094  Random_series_134  Random_series_174
# Random_series_015  Random_series_055  Random_series_095  Random_series_135  Random_series_175
# Random_series_016  Random_series_056  Random_series_096  Random_series_136  Random_series_176
# Random_series_017  Random_series_057  Random_series_097  Random_series_137  Random_series_177
# Random_series_018  Random_series_058  Random_series_098  Random_series_138  Random_series_178
# Random_series_019  Random_series_059  Random_series_099  Random_series_139  Random_series_179
# Random_series_020  Random_series_060  Random_series_100  Random_series_140  Random_series_180
# Random_series_021  Random_series_061  Random_series_101  Random_series_141  Random_series_181
# Random_series_022  Random_series_062  Random_series_102  Random_series_142  Random_series_182
# Random_series_023  Random_series_063  Random_series_103  Random_series_143  Random_series_183
# Random_series_024  Random_series_064  Random_series_104  Random_series_144  Random_series_184
# Random_series_025  Random_series_065  Random_series_105  Random_series_145  Random_series_185
# Random_series_026  Random_series_066  Random_series_106  Random_series_146  Random_series_186
# Random_series_027  Random_series_067  Random_series_107  Random_series_147  Random_series_187
# Random_series_028  Random_series_068  Random_series_108  Random_series_148  Random_series_188
# Random_series_029  Random_series_069  Random_series_109  Random_series_149  Random_series_189
# Random_series_030  Random_series_070  Random_series_110  Random_series_150  Random_series_190
# Random_series_031  Random_series_071  Random_series_111  Random_series_151  Random_series_191
# Random_series_032  Random_series_072  Random_series_112  Random_series_152  Random_series_192
# Random_series_033  Random_series_073  Random_series_113  Random_series_153  Random_series_193
# Random_series_034  Random_series_074  Random_series_114  Random_series_154  Random_series_194
# Random_series_035  Random_series_075  Random_series_115  Random_series_155  Random_series_195
# Random_series_036  Random_series_076  Random_series_116  Random_series_156  Random_series_196
# Random_series_037  Random_series_077  Random_series_117  Random_series_157  Random_series_197
# Random_series_038  Random_series_078  Random_series_118  Random_series_158  Random_series_198
# Random_series_039  Random_series_079  Random_series_119  Random_series_159  Random_series_199
# Random_series_040  Random_series_080  Random_series_120  Random_series_160  Random_series_200

# %%
import os
import fnmatch
import pandas as pd
import json

# %%
path_list = []
for root, dirs, files in os.walk('/content/drive/My Drive/Random_series'):
    # print(root)
    if len(root)>2:
        path_list.append(root)

path_list = sorted(path_list[1:])
path_list
# Out:
# ['/content/drive/My Drive/Random_series/Random_series_001',
#  '/content/drive/My Drive/Random_series/Random_series_002',
#  '/content/drive/My Drive/Random_series/Random_series_003',
#  '/content/drive/My Drive/Random_series/Random_series_004',
#  '/content/drive/My Drive/Random_series/Random_series_005',
#  '/content/drive/My Drive/Random_series/Random_series_006',
#  '/content/drive/My Drive/Random_series/Random_series_007',
#  '/content/drive/My Drive/Random_series/Random_series_008',
#  '/content/drive/My Drive/Random_series/Random_series_009',
#  '/content/drive/My Drive/Random_series/Random_series_010',
#  '/content/drive/My Drive/Random_series/Random_series_011',
#  '/content/drive/My Drive/Random_series/Random_series_012',
#  '/content/drive/My Drive/Random_series/Random_series_013',
#  '/content/drive/My Drive/Random_series/Random_series_014',
#  '/content/drive/My Drive/Random_series/Random_series_015',
#  '/content/drive/My Drive/Random_series/Random_series_016',
#  '/content/drive/My Drive/Random_series/Random_series_017',
#  '/content/drive/My Drive/Random_series/Random_series_018',
#  '/content/drive/My Drive/Random_series/Random_series_019',
#  '/content/drive/My Drive/Random_series/Random_series_020',
#  '/content/drive/My Drive/Random_series/Random_series_021',
#  '/content/drive/My Drive/Random_series/Random_series_022',
#  '/content/drive/My Drive/Random_series/Random_series_023',
#  '/content/drive/My Drive/Random_series/Random_series_024',
#  '/content/drive/My Drive/Random_series/Random_series_025',
#  '/content/drive/My Drive/Random_series/Random_series_026',
#  '/content/drive/My Drive/Random_series/Random_series_027',
#  '/content/drive/My Drive/Random_series/Random_series_028',
#  '/content/drive/My Drive/Random_series/Random_series_029',
#  '/content/drive/My Drive/Random_series/Random_series_030',
#  '/content/drive/My Drive/Random_series/Random_series_031',
#  '/content/drive/My Drive/Random_series/Random_series_032',
#  '/content/drive/My Drive/Random_series/Random_series_033',
#  '/content/drive/My Drive/Random_series/Random_series_034',
#  '/content/drive/My Drive/Random_series/Random_series_035',
#  '/content/drive/My Drive/Random_series/Random_series_036',
#  '/content/drive/My Drive/Random_series/Random_series_037',
#  '/content/drive/My Drive/Random_series/Random_series_038',
#  '/content/drive/My Drive/Random_series/Random_series_039',
#  '/content/drive/My Drive/Random_series/Random_series_040',
#  '/content/drive/My Drive/Random_series/Random_series_041',
#  '/content/drive/My Drive/Random_series/Random_series_042',
#  '/content/drive/My Drive/Random_series/Random_series_043',
#  '/content/drive/My Drive/Random_series/Random_series_044',
#  '/content/drive/My Drive/Random_series/Random_series_045',
#  '/content/drive/My Drive/Random_series/Random_series_046',
#  '/content/drive/My Drive/Random_series/Random_series_047',
#  '/content/drive/My Drive/Random_series/Random_series_048',
#  '/content/drive/My Drive/Random_series/Random_series_049',
#  '/content/drive/My Drive/Random_series/Random_series_050',
#  '/content/drive/My Drive/Random_series/Random_series_051',
#  '/content/drive/My Drive/Random_series/Random_series_052',
#  '/content/drive/My Drive/Random_series/Random_series_053',
#  '/content/drive/My Drive/Random_series/Random_series_054',
#  '/content/drive/My Drive/Random_series/Random_series_055',
#  '/content/drive/My Drive/Random_series/Random_series_056',
#  '/content/drive/My Drive/Random_series/Random_series_057',
#  '/content/drive/My Drive/Random_series/Random_series_058',
#  '/content/drive/My Drive/Random_series/Random_series_059',
#  '/content/drive/My Drive/Random_series/Random_series_060',
#  '/content/drive/My Drive/Random_series/Random_series_061',
#  '/content/drive/My Drive/Random_series/Random_series_062',
#  '/content/drive/My Drive/Random_series/Random_series_063',
#  '/content/drive/My Drive/Random_series/Random_series_064',
#  '/content/drive/My Drive/Random_series/Random_series_065',
#  '/content/drive/My Drive/Random_series/Random_series_066',
#  '/content/drive/My Drive/Random_series/Random_series_067',
#  '/content/drive/My Drive/Random_series/Random_series_068',
#  '/content/drive/My Drive/Random_series/Random_series_069',
#  '/content/drive/My Drive/Random_series/Random_series_070',
#  '/content/drive/My Drive/Random_series/Random_series_071',
#  '/content/drive/My Drive/Random_series/Random_series_072',
#  '/content/drive/My Drive/Random_series/Random_series_073',
#  '/content/drive/My Drive/Random_series/Random_series_074',
#  '/content/drive/My Drive/Random_series/Random_series_075',
#  '/content/drive/My Drive/Random_series/Random_series_076',
#  '/content/drive/My Drive/Random_series/Random_series_077',
#  '/content/drive/My Drive/Random_series/Random_series_078',
#  '/content/drive/My Drive/Random_series/Random_series_079',
#  '/content/drive/My Drive/Random_series/Random_series_080',
#  '/content/drive/My Drive/Random_series/Random_series_081',
#  '/content/drive/My Drive/Random_series/Random_series_082',
#  '/content/drive/My Drive/Random_series/Random_series_083',
#  '/content/drive/My Drive/Random_series/Random_series_084',
#  '/content/drive/My Drive/Random_series/Random_series_085',
#  '/content/drive/My Drive/Random_series/Random_series_086',
#  '/content/drive/My Drive/Random_series/Random_series_087',
#  '/content/drive/My Drive/Random_series/Random_series_088',
#  '/content/drive/My Drive/Random_series/Random_series_089',
#  '/content/drive/My Drive/Random_series/Random_series_090',
#  '/content/drive/My Drive/Random_series/Random_series_091',
#  '/content/drive/My Drive/Random_series/Random_series_092',
#  '/content/drive/My Drive/Random_series/Random_series_093',
#  '/content/drive/My Drive/Random_series/Random_series_094',
#  '/content/drive/My Drive/Random_series/Random_series_095',
#  '/content/drive/My Drive/Random_series/Random_series_096',
#  '/content/drive/My Drive/Random_series/Random_series_097',
#  '/content/drive/My Drive/Random_series/Random_series_098',
#  '/content/drive/My Drive/Random_series/Random_series_099',
#  '/content/drive/My Drive/Random_series/Random_series_100',
#  '/content/drive/My Drive/Random_series/Random_series_101',
#  '/content/drive/My Drive/Random_series/Random_series_102',
#  '/content/drive/My Drive/Random_series/Random_series_103',
#  '/content/drive/My Drive/Random_series/Random_series_104',
#  '/content/drive/My Drive/Random_series/Random_series_105',
#  '/content/drive/My Drive/Random_series/Random_series_106',
#  '/content/drive/My Drive/Random_series/Random_series_107',
#  '/content/drive/My Drive/Random_series/Random_series_108',
#  '/content/drive/My Drive/Random_series/Random_series_109',
#  '/content/drive/My Drive/Random_series/Random_series_110',
#  '/content/drive/My Drive/Random_series/Random_series_111',
#  '/content/drive/My Drive/Random_series/Random_series_112',
#  '/content/drive/My Drive/Random_series/Random_series_113',
#  '/content/drive/My Drive/Random_series/Random_series_114',
#  '/content/drive/My Drive/Random_series/Random_series_115',
#  '/content/drive/My Drive/Random_series/Random_series_116',
#  '/content/drive/My Drive/Random_series/Random_series_117',
#  '/content/drive/My Drive/Random_series/Random_series_118',
#  '/content/drive/My Drive/Random_series/Random_series_119',
#  '/content/drive/My Drive/Random_series/Random_series_120',
#  '/content/drive/My Drive/Random_series/Random_series_121',
#  '/content/drive/My Drive/Random_series/Random_series_122',
#  '/content/drive/My Drive/Random_series/Random_series_123',
#  '/content/drive/My Drive/Random_series/Random_series_124',
#  '/content/drive/My Drive/Random_series/Random_series_125',
#  '/content/drive/My Drive/Random_series/Random_series_126',
#  '/content/drive/My Drive/Random_series/Random_series_127',
#  '/content/drive/My Drive/Random_series/Random_series_128',
#  '/content/drive/My Drive/Random_series/Random_series_129',
#  '/content/drive/My Drive/Random_series/Random_series_130',
#  '/content/drive/My Drive/Random_series/Random_series_131',
#  '/content/drive/My Drive/Random_series/Random_series_132',
#  '/content/drive/My Drive/Random_series/Random_series_133',
#  '/content/drive/My Drive/Random_series/Random_series_134',
#  '/content/drive/My Drive/Random_series/Random_series_135',
#  '/content/drive/My Drive/Random_series/Random_series_136',
#  '/content/drive/My Drive/Random_series/Random_series_137',
#  '/content/drive/My Drive/Random_series/Random_series_138',
#  '/content/drive/My Drive/Random_series/Random_series_139',
#  '/content/drive/My Drive/Random_series/Random_series_140',
#  '/content/drive/My Drive/Random_series/Random_series_141',
#  '/content/drive/My Drive/Random_series/Random_series_142',
#  '/content/drive/My Drive/Random_series/Random_series_143',
#  '/content/drive/My Drive/Random_series/Random_series_144',
#  '/content/drive/My Drive/Random_series/Random_series_145',
#  '/content/drive/My Drive/Random_series/Random_series_146',
#  '/content/drive/My Drive/Random_series/Random_series_147',
#  '/content/drive/My Drive/Random_series/Random_series_148',
#  '/content/drive/My Drive/Random_series/Random_series_149',
#  '/content/drive/My Drive/Random_series/Random_series_150',
#  '/content/drive/My Drive/Random_series/Random_series_151',
#  '/content/drive/My Drive/Random_series/Random_series_152',
#  '/content/drive/My Drive/Random_series/Random_series_153',
#  '/content/drive/My Drive/Random_series/Random_series_154',
#  '/content/drive/My Drive/Random_series/Random_series_155',
#  '/content/drive/My Drive/Random_series/Random_series_156',
#  '/content/drive/My Drive/Random_series/Random_series_157',
#  '/content/drive/My Drive/Random_series/Random_series_158',
#  '/content/drive/My Drive/Random_series/Random_series_159',
#  '/content/drive/My Drive/Random_series/Random_series_160',
#  '/content/drive/My Drive/Random_series/Random_series_161',
#  '/content/drive/My Drive/Random_series/Random_series_162',
#  '/content/drive/My Drive/Random_series/Random_series_163',
#  '/content/drive/My Drive/Random_series/Random_series_164',
#  '/content/drive/My Drive/Random_series/Random_series_165',
#  '/content/drive/My Drive/Random_series/Random_series_166',
#  '/content/drive/My Drive/Random_series/Random_series_167',
#  '/content/drive/My Drive/Random_series/Random_series_168',
#  '/content/drive/My Drive/Random_series/Random_series_169',
#  '/content/drive/My Drive/Random_series/Random_series_170',
#  '/content/drive/My Drive/Random_series/Random_series_171',
#  '/content/drive/My Drive/Random_series/Random_series_172',
#  '/content/drive/My Drive/Random_series/Random_series_173',
#  '/content/drive/My Drive/Random_series/Random_series_174',
#  '/content/drive/My Drive/Random_series/Random_series_175',
#  '/content/drive/My Drive/Random_series/Random_series_176',
#  '/content/drive/My Drive/Random_series/Random_series_177',
#  '/content/drive/My Drive/Random_series/Random_series_178',
#  '/content/drive/My Drive/Random_series/Random_series_179',
#  '/content/drive/My Drive/Random_series/Random_series_180',
#  '/content/drive/My Drive/Random_series/Random_series_181',
#  '/content/drive/My Drive/Random_series/Random_series_182',
#  '/content/drive/My Drive/Random_series/Random_series_183',
#  '/content/drive/My Drive/Random_series/Random_series_184',
#  '/content/drive/My Drive/Random_series/Random_series_185',
#  '/content/drive/My Drive/Random_series/Random_series_186',
#  '/content/drive/My Drive/Random_series/Random_series_187',
#  '/content/drive/My Drive/Random_series/Random_series_188',
#  '/content/drive/My Drive/Random_series/Random_series_189',
#  '/content/drive/My Drive/Random_series/Random_series_190',
#  '/content/drive/My Drive/Random_series/Random_series_191',
#  '/content/drive/My Drive/Random_series/Random_series_192',
#  '/content/drive/My Drive/Random_series/Random_series_193',
#  '/content/drive/My Drive/Random_series/Random_series_194',
#  '/content/drive/My Drive/Random_series/Random_series_195',
#  '/content/drive/My Drive/Random_series/Random_series_196',
#  '/content/drive/My Drive/Random_series/Random_series_197',
#  '/content/drive/My Drive/Random_series/Random_series_198',
#  '/content/drive/My Drive/Random_series/Random_series_199',
#  '/content/drive/My Drive/Random_series/Random_series_200']

# %%
# '/content/drive/My Drive/Random_series/Time_series', '/content/drive/My Drive/Random_series/Flux_series', '/content/drive/My Drive/Random_series/Boundary_series'
#

# %%
# # Example: Removing specific paths
# paths_to_remove = ['/content/drive/My Drive/Random_series/Time_series', '/content/drive/My Drive/Random_series/Flux_series', '/content/drive/My Drive/Random_series/Boundary_series']

# # Using list comprehension
# path_list = [path for path in path_list if path not in paths_to_remove]

# path_list

# %%
import os
import fnmatch
import pandas as pd
import json

# %%
len(path_list)
# Out:
# 200

# %%
# import pandas as pd

# # Initialize the new path list
# new_path_list = []

# # Loop through each path
# for path in path_list:
#     # Read the CSV file
#     print(path)
#     data = pd.read_csv(f'{path}/image_data_1.csv')
#     df = pd.DataFrame(data)

#     # Check if all rows in the 'target' column have the same value
#     if len(df['target'].unique()) > 0:  # More than one unique value means mixed classes
#         new_path_list.append(path)

# # Print the resulting list of paths
# print("Filtered paths:")
# new_path_list

# %%
# len(new_path_list)

# %%
import random
import os

# Define categories based on the folder names
random_series_paths = [path for path in path_list if 'Random_series_' in path]
# flux_series_paths = [path for path in new_path_list if 'Flux_series_' in path]
# time_series_paths = [path for path in new_path_list if 'Time_series_' in path]
# boundary_series_paths = [path for path in new_path_list if 'Boundary_series_' in path]
random.shuffle(random_series_paths)
# Split function to divide data into 3:1:1 ratio
def split_dataset(category_paths, ratio=(2, 1, 1)):
    total_size = len(category_paths)
    part1_size = (ratio[0] / sum(ratio)) * total_size
    part2_size = (ratio[1] / sum(ratio)) * total_size
    part3_size = (ratio[2] / sum(ratio)) * total_size

    part1 = category_paths[:int(part1_size)]
    part2 = category_paths[int(part1_size):int(part1_size + part2_size)]
    part3 = category_paths[int(part1_size + part2_size):]

    return part1, part2, part3

# Split each category
random_part1, random_part2, random_part3 = split_dataset(random_series_paths)
# flux_part1, flux_part2, flux_part3 = split_dataset(flux_series_paths)
# time_part1, time_part2, time_part3 = split_dataset(time_series_paths)
# boundary_part1, boundary_part2, boundary_part3 = split_dataset(boundary_series_paths)

# Combine the splits while keeping the balance
train_split = random_part1
val_split = random_part2
test_split = random_part3

# # Shuffle the final splits to ensure randomness within each split
# random.shuffle(split1)
# random.shuffle(split2)
# random.shuffle(split3)

# Now you have the three splits
print(train_split)
print(len(train_split))
print(val_split)
print(len(val_split))
print(test_split)
print(len(test_split))
# Out:
# ['/content/drive/My Drive/Random_series/Random_series_014', '/content/drive/My Drive/Random_series/Random_series_023', '/content/drive/My Drive/Random_series/Random_series_003', '/content/drive/My Drive/Random_series/Random_series_143', '/content/drive/My Drive/Random_series/Random_series_049', '/content/drive/My Drive/Random_series/Random_series_156', '/content/drive/My Drive/Random_series/Random_series_181', '/content/drive/My Drive/Random_series/Random_series_147', '/content/drive/My Drive/Random_series/Random_series_059', '/content/drive/My Drive/Random_series/Random_series_179', '/content/drive/My Drive/Random_series/Random_series_077', '/content/drive/My Drive/Random_series/Random_series_180', '/content/drive/My Drive/Random_series/Random_series_085', '/content/drive/My Drive/Random_series/Random_series_110', '/content/drive/My Drive/Random_series/Random_series_001', '/content/drive/My Drive/Random_series/Random_series_012', '/content/drive/My Drive/Random_series/Random_series_025', '/content/drive/My Drive/Random_series/Random_series_131', '/content/drive/My Drive/Random_series/Random_series_107', '/content/drive/My Drive/Random_series/Random_series_129', '/content/drive/My Drive/Random_series/Random_series_065', '/content/drive/My Drive/Random_series/Random_series_048', '/content/drive/My Drive/Random_series/Random_series_017', '/content/drive/My Drive/Random_series/Random_series_064', '/content/drive/My Drive/Random_series/Random_series_101', '/content/drive/My Drive/Random_series/Random_series_043', '/content/drive/My Drive/Random_series/Random_series_128', '/content/drive/My Drive/Random_series/Random_series_152', '/content/drive/My Drive/Random_series/Random_series_144', '/content/drive/My Drive/Random_series/Random_series_039', '/content/drive/My Drive/Random_series/Random_series_178', '/content/drive/My Drive/Random_series/Random_series_055', '/content/drive/My Drive/Random_series/Random_series_020', '/content/drive/My Drive/Random_series/Random_series_028', '/content/drive/My Drive/Random_series/Random_series_146', '/content/drive/My Drive/Random_series/Random_series_190', '/content/drive/My Drive/Random_series/Random_series_026', '/content/drive/My Drive/Random_series/Random_series_185', '/content/drive/My Drive/Random_series/Random_series_084', '/content/drive/My Drive/Random_series/Random_series_172', '/content/drive/My Drive/Random_series/Random_series_137', '/content/drive/My Drive/Random_series/Random_series_095', '/content/drive/My Drive/Random_series/Random_series_161', '/content/drive/My Drive/Random_series/Random_series_102', '/content/drive/My Drive/Random_series/Random_series_187', '/content/drive/My Drive/Random_series/Random_series_032', '/content/drive/My Drive/Random_series/Random_series_109', '/content/drive/My Drive/Random_series/Random_series_141', '/content/drive/My Drive/Random_series/Random_series_047', '/content/drive/My Drive/Random_series/Random_series_092', '/content/drive/My Drive/Random_series/Random_series_079', '/content/drive/My Drive/Random_series/Random_series_125', '/content/drive/My Drive/Random_series/Random_series_188', '/content/drive/My Drive/Random_series/Random_series_080', '/content/drive/My Drive/Random_series/Random_series_150', '/content/drive/My Drive/Random_series/Random_series_069', '/content/drive/My Drive/Random_series/Random_series_087', '/content/drive/My Drive/Random_series/Random_series_123', '/content/drive/My Drive/Random_series/Random_series_169', '/content/drive/My Drive/Random_series/Random_series_019', '/content/drive/My Drive/Random_series/Random_series_075', '/content/drive/My Drive/Random_series/Random_series_192', '/content/drive/My Drive/Random_series/Random_series_093', '/content/drive/My Drive/Random_series/Random_series_111', '/content/drive/My Drive/Random_series/Random_series_164', '/content/drive/My Drive/Random_series/Random_series_037', '/content/drive/My Drive/Random_series/Random_series_029', '/content/drive/My Drive/Random_series/Random_ ...
# 100
# ['/content/drive/My Drive/Random_series/Random_series_142', '/content/drive/My Drive/Random_series/Random_series_011', '/content/drive/My Drive/Random_series/Random_series_127', '/content/drive/My Drive/Random_series/Random_series_117', '/content/drive/My Drive/Random_series/Random_series_136', '/content/drive/My Drive/Random_series/Random_series_158', '/content/drive/My Drive/Random_series/Random_series_042', '/content/drive/My Drive/Random_series/Random_series_114', '/content/drive/My Drive/Random_series/Random_series_040', '/content/drive/My Drive/Random_series/Random_series_184', '/content/drive/My Drive/Random_series/Random_series_113', '/content/drive/My Drive/Random_series/Random_series_031', '/content/drive/My Drive/Random_series/Random_series_094', '/content/drive/My Drive/Random_series/Random_series_163', '/content/drive/My Drive/Random_series/Random_series_200', '/content/drive/My Drive/Random_series/Random_series_162', '/content/drive/My Drive/Random_series/Random_series_015', '/content/drive/My Drive/Random_series/Random_series_027', '/content/drive/My Drive/Random_series/Random_series_010', '/content/drive/My Drive/Random_series/Random_series_149', '/content/drive/My Drive/Random_series/Random_series_196', '/content/drive/My Drive/Random_series/Random_series_009', '/content/drive/My Drive/Random_series/Random_series_018', '/content/drive/My Drive/Random_series/Random_series_124', '/content/drive/My Drive/Random_series/Random_series_044', '/content/drive/My Drive/Random_series/Random_series_173', '/content/drive/My Drive/Random_series/Random_series_155', '/content/drive/My Drive/Random_series/Random_series_060', '/content/drive/My Drive/Random_series/Random_series_030', '/content/drive/My Drive/Random_series/Random_series_074', '/content/drive/My Drive/Random_series/Random_series_021', '/content/drive/My Drive/Random_series/Random_series_140', '/content/drive/My Drive/Random_series/Random_series_068', '/content/drive/My Drive/Random_series/Random_series_157', '/content/drive/My Drive/Random_series/Random_series_103', '/content/drive/My Drive/Random_series/Random_series_174', '/content/drive/My Drive/Random_series/Random_series_071', '/content/drive/My Drive/Random_series/Random_series_099', '/content/drive/My Drive/Random_series/Random_series_072', '/content/drive/My Drive/Random_series/Random_series_073', '/content/drive/My Drive/Random_series/Random_series_160', '/content/drive/My Drive/Random_series/Random_series_089', '/content/drive/My Drive/Random_series/Random_series_133', '/content/drive/My Drive/Random_series/Random_series_063', '/content/drive/My Drive/Random_series/Random_series_112', '/content/drive/My Drive/Random_series/Random_series_061', '/content/drive/My Drive/Random_series/Random_series_100', '/content/drive/My Drive/Random_series/Random_series_176', '/content/drive/My Drive/Random_series/Random_series_034', '/content/drive/My Drive/Random_series/Random_series_007']
# 50
# ['/content/drive/My Drive/Random_series/Random_series_165', '/content/drive/My Drive/Random_series/Random_series_189', '/content/drive/My Drive/Random_series/Random_series_033', '/content/drive/My Drive/Random_series/Random_series_119', '/content/drive/My Drive/Random_series/Random_series_005', '/content/drive/My Drive/Random_series/Random_series_097', '/content/drive/My Drive/Random_series/Random_series_083', '/content/drive/My Drive/Random_series/Random_series_008', '/content/drive/My Drive/Random_series/Random_series_041', '/content/drive/My Drive/Random_series/Random_series_135', '/content/drive/My Drive/Random_series/Random_series_098', '/content/drive/My Drive/Random_series/Random_series_016', '/content/drive/My Drive/Random_series/Random_series_057', '/content/drive/My Drive/Random_series/Random_series_050', '/content/drive/My Drive/Random_series/Random_series_198', '/content/drive/My Drive/Random_series/Random_series_138', '/content/drive/My Drive/Random_series/Random_series_153', '/content/drive/My Drive/Random_series/Random_series_171', '/content/drive/My Drive/Random_series/Random_series_120', '/content/drive/My Drive/Random_series/Random_series_078', '/content/drive/My Drive/Random_series/Random_series_130', '/content/drive/My Drive/Random_series/Random_series_104', '/content/drive/My Drive/Random_series/Random_series_091', '/content/drive/My Drive/Random_series/Random_series_186', '/content/drive/My Drive/Random_series/Random_series_139', '/content/drive/My Drive/Random_series/Random_series_076', '/content/drive/My Drive/Random_series/Random_series_082', '/content/drive/My Drive/Random_series/Random_series_193', '/content/drive/My Drive/Random_series/Random_series_004', '/content/drive/My Drive/Random_series/Random_series_148', '/content/drive/My Drive/Random_series/Random_series_170', '/content/drive/My Drive/Random_series/Random_series_145', '/content/drive/My Drive/Random_series/Random_series_126', '/content/drive/My Drive/Random_series/Random_series_036', '/content/drive/My Drive/Random_series/Random_series_052', '/content/drive/My Drive/Random_series/Random_series_013', '/content/drive/My Drive/Random_series/Random_series_058', '/content/drive/My Drive/Random_series/Random_series_167', '/content/drive/My Drive/Random_series/Random_series_105', '/content/drive/My Drive/Random_series/Random_series_166', '/content/drive/My Drive/Random_series/Random_series_118', '/content/drive/My Drive/Random_series/Random_series_046', '/content/drive/My Drive/Random_series/Random_series_159', '/content/drive/My Drive/Random_series/Random_series_067', '/content/drive/My Drive/Random_series/Random_series_121', '/content/drive/My Drive/Random_series/Random_series_183', '/content/drive/My Drive/Random_series/Random_series_053', '/content/drive/My Drive/Random_series/Random_series_002', '/content/drive/My Drive/Random_series/Random_series_070', '/content/drive/My Drive/Random_series/Random_series_191']
# 50

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Enhanced Images

# %% [markdown]
# #UNet Model

# %%
train_directories = train_split
val_directories = val_split
test_directories = test_split

print(train_directories)
print(val_directories)
print(test_directories)
# Out:
# ['/content/drive/My Drive/Random_series/Random_series_014', '/content/drive/My Drive/Random_series/Random_series_023', '/content/drive/My Drive/Random_series/Random_series_003', '/content/drive/My Drive/Random_series/Random_series_143', '/content/drive/My Drive/Random_series/Random_series_049', '/content/drive/My Drive/Random_series/Random_series_156', '/content/drive/My Drive/Random_series/Random_series_181', '/content/drive/My Drive/Random_series/Random_series_147', '/content/drive/My Drive/Random_series/Random_series_059', '/content/drive/My Drive/Random_series/Random_series_179', '/content/drive/My Drive/Random_series/Random_series_077', '/content/drive/My Drive/Random_series/Random_series_180', '/content/drive/My Drive/Random_series/Random_series_085', '/content/drive/My Drive/Random_series/Random_series_110', '/content/drive/My Drive/Random_series/Random_series_001', '/content/drive/My Drive/Random_series/Random_series_012', '/content/drive/My Drive/Random_series/Random_series_025', '/content/drive/My Drive/Random_series/Random_series_131', '/content/drive/My Drive/Random_series/Random_series_107', '/content/drive/My Drive/Random_series/Random_series_129', '/content/drive/My Drive/Random_series/Random_series_065', '/content/drive/My Drive/Random_series/Random_series_048', '/content/drive/My Drive/Random_series/Random_series_017', '/content/drive/My Drive/Random_series/Random_series_064', '/content/drive/My Drive/Random_series/Random_series_101', '/content/drive/My Drive/Random_series/Random_series_043', '/content/drive/My Drive/Random_series/Random_series_128', '/content/drive/My Drive/Random_series/Random_series_152', '/content/drive/My Drive/Random_series/Random_series_144', '/content/drive/My Drive/Random_series/Random_series_039', '/content/drive/My Drive/Random_series/Random_series_178', '/content/drive/My Drive/Random_series/Random_series_055', '/content/drive/My Drive/Random_series/Random_series_020', '/content/drive/My Drive/Random_series/Random_series_028', '/content/drive/My Drive/Random_series/Random_series_146', '/content/drive/My Drive/Random_series/Random_series_190', '/content/drive/My Drive/Random_series/Random_series_026', '/content/drive/My Drive/Random_series/Random_series_185', '/content/drive/My Drive/Random_series/Random_series_084', '/content/drive/My Drive/Random_series/Random_series_172', '/content/drive/My Drive/Random_series/Random_series_137', '/content/drive/My Drive/Random_series/Random_series_095', '/content/drive/My Drive/Random_series/Random_series_161', '/content/drive/My Drive/Random_series/Random_series_102', '/content/drive/My Drive/Random_series/Random_series_187', '/content/drive/My Drive/Random_series/Random_series_032', '/content/drive/My Drive/Random_series/Random_series_109', '/content/drive/My Drive/Random_series/Random_series_141', '/content/drive/My Drive/Random_series/Random_series_047', '/content/drive/My Drive/Random_series/Random_series_092', '/content/drive/My Drive/Random_series/Random_series_079', '/content/drive/My Drive/Random_series/Random_series_125', '/content/drive/My Drive/Random_series/Random_series_188', '/content/drive/My Drive/Random_series/Random_series_080', '/content/drive/My Drive/Random_series/Random_series_150', '/content/drive/My Drive/Random_series/Random_series_069', '/content/drive/My Drive/Random_series/Random_series_087', '/content/drive/My Drive/Random_series/Random_series_123', '/content/drive/My Drive/Random_series/Random_series_169', '/content/drive/My Drive/Random_series/Random_series_019', '/content/drive/My Drive/Random_series/Random_series_075', '/content/drive/My Drive/Random_series/Random_series_192', '/content/drive/My Drive/Random_series/Random_series_093', '/content/drive/My Drive/Random_series/Random_series_111', '/content/drive/My Drive/Random_series/Random_series_164', '/content/drive/My Drive/Random_series/Random_series_037', '/content/drive/My Drive/Random_series/Random_series_029', '/content/drive/My Drive/Random_series/Random_ ...
# ['/content/drive/My Drive/Random_series/Random_series_142', '/content/drive/My Drive/Random_series/Random_series_011', '/content/drive/My Drive/Random_series/Random_series_127', '/content/drive/My Drive/Random_series/Random_series_117', '/content/drive/My Drive/Random_series/Random_series_136', '/content/drive/My Drive/Random_series/Random_series_158', '/content/drive/My Drive/Random_series/Random_series_042', '/content/drive/My Drive/Random_series/Random_series_114', '/content/drive/My Drive/Random_series/Random_series_040', '/content/drive/My Drive/Random_series/Random_series_184', '/content/drive/My Drive/Random_series/Random_series_113', '/content/drive/My Drive/Random_series/Random_series_031', '/content/drive/My Drive/Random_series/Random_series_094', '/content/drive/My Drive/Random_series/Random_series_163', '/content/drive/My Drive/Random_series/Random_series_200', '/content/drive/My Drive/Random_series/Random_series_162', '/content/drive/My Drive/Random_series/Random_series_015', '/content/drive/My Drive/Random_series/Random_series_027', '/content/drive/My Drive/Random_series/Random_series_010', '/content/drive/My Drive/Random_series/Random_series_149', '/content/drive/My Drive/Random_series/Random_series_196', '/content/drive/My Drive/Random_series/Random_series_009', '/content/drive/My Drive/Random_series/Random_series_018', '/content/drive/My Drive/Random_series/Random_series_124', '/content/drive/My Drive/Random_series/Random_series_044', '/content/drive/My Drive/Random_series/Random_series_173', '/content/drive/My Drive/Random_series/Random_series_155', '/content/drive/My Drive/Random_series/Random_series_060', '/content/drive/My Drive/Random_series/Random_series_030', '/content/drive/My Drive/Random_series/Random_series_074', '/content/drive/My Drive/Random_series/Random_series_021', '/content/drive/My Drive/Random_series/Random_series_140', '/content/drive/My Drive/Random_series/Random_series_068', '/content/drive/My Drive/Random_series/Random_series_157', '/content/drive/My Drive/Random_series/Random_series_103', '/content/drive/My Drive/Random_series/Random_series_174', '/content/drive/My Drive/Random_series/Random_series_071', '/content/drive/My Drive/Random_series/Random_series_099', '/content/drive/My Drive/Random_series/Random_series_072', '/content/drive/My Drive/Random_series/Random_series_073', '/content/drive/My Drive/Random_series/Random_series_160', '/content/drive/My Drive/Random_series/Random_series_089', '/content/drive/My Drive/Random_series/Random_series_133', '/content/drive/My Drive/Random_series/Random_series_063', '/content/drive/My Drive/Random_series/Random_series_112', '/content/drive/My Drive/Random_series/Random_series_061', '/content/drive/My Drive/Random_series/Random_series_100', '/content/drive/My Drive/Random_series/Random_series_176', '/content/drive/My Drive/Random_series/Random_series_034', '/content/drive/My Drive/Random_series/Random_series_007']
# ['/content/drive/My Drive/Random_series/Random_series_165', '/content/drive/My Drive/Random_series/Random_series_189', '/content/drive/My Drive/Random_series/Random_series_033', '/content/drive/My Drive/Random_series/Random_series_119', '/content/drive/My Drive/Random_series/Random_series_005', '/content/drive/My Drive/Random_series/Random_series_097', '/content/drive/My Drive/Random_series/Random_series_083', '/content/drive/My Drive/Random_series/Random_series_008', '/content/drive/My Drive/Random_series/Random_series_041', '/content/drive/My Drive/Random_series/Random_series_135', '/content/drive/My Drive/Random_series/Random_series_098', '/content/drive/My Drive/Random_series/Random_series_016', '/content/drive/My Drive/Random_series/Random_series_057', '/content/drive/My Drive/Random_series/Random_series_050', '/content/drive/My Drive/Random_series/Random_series_198', '/content/drive/My Drive/Random_series/Random_series_138', '/content/drive/My Drive/Random_series/Random_series_153', '/content/drive/My Drive/Random_series/Random_series_171', '/content/drive/My Drive/Random_series/Random_series_120', '/content/drive/My Drive/Random_series/Random_series_078', '/content/drive/My Drive/Random_series/Random_series_130', '/content/drive/My Drive/Random_series/Random_series_104', '/content/drive/My Drive/Random_series/Random_series_091', '/content/drive/My Drive/Random_series/Random_series_186', '/content/drive/My Drive/Random_series/Random_series_139', '/content/drive/My Drive/Random_series/Random_series_076', '/content/drive/My Drive/Random_series/Random_series_082', '/content/drive/My Drive/Random_series/Random_series_193', '/content/drive/My Drive/Random_series/Random_series_004', '/content/drive/My Drive/Random_series/Random_series_148', '/content/drive/My Drive/Random_series/Random_series_170', '/content/drive/My Drive/Random_series/Random_series_145', '/content/drive/My Drive/Random_series/Random_series_126', '/content/drive/My Drive/Random_series/Random_series_036', '/content/drive/My Drive/Random_series/Random_series_052', '/content/drive/My Drive/Random_series/Random_series_013', '/content/drive/My Drive/Random_series/Random_series_058', '/content/drive/My Drive/Random_series/Random_series_167', '/content/drive/My Drive/Random_series/Random_series_105', '/content/drive/My Drive/Random_series/Random_series_166', '/content/drive/My Drive/Random_series/Random_series_118', '/content/drive/My Drive/Random_series/Random_series_046', '/content/drive/My Drive/Random_series/Random_series_159', '/content/drive/My Drive/Random_series/Random_series_067', '/content/drive/My Drive/Random_series/Random_series_121', '/content/drive/My Drive/Random_series/Random_series_183', '/content/drive/My Drive/Random_series/Random_series_053', '/content/drive/My Drive/Random_series/Random_series_002', '/content/drive/My Drive/Random_series/Random_series_070', '/content/drive/My Drive/Random_series/Random_series_191']

# %%
print(len(train_directories))
print(len(val_directories))
print(len(test_directories))
# Out:
# 100
# 50
# 50

# %%
import cv2
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.utils import to_categorical, Sequence
import matplotlib.pyplot as plt

# %%
# for directory in train_directories:
#     file_path = os.path.join(directory, 'image_data_1.csv')

#     if os.path.exists(file_path):
#         df = pd.read_csv(file_path)

#         combined_data = pd.concat([combined_data, df], ignore_index=True)
#     else:
#         print(f"File not found: {file_path}")

# combined_data.to_csv('train_data.csv', index=False)


# Define global parameters
point_radius = 5
input_channels = 8

# Crop images
def combine_data_and_images(image_R, image_T):
    left = 135
    upper = 13
    right = 740
    lower = 618
    # Use numpy slicing to crop
    cropped_image_R = image_R[upper:lower, left:right]
    cropped_image_T = image_T[upper:lower, left:right]
    return cropped_image_R, cropped_image_T

# # Get all data paths in the dataset
# def get_data_paths(data_dir):
#     data_paths = []
#     for directory in data_dir:
#         # Convert filenames to lowercase for easier matching
#         # files_lower = [f.lower() for f in files]
#         required_files = ['Filtered_R_Image.tif', 'Filtered_T_Image.tif', 'image_data_1.csv']
#         for i in required_files:
#             file_path = os.path.join(directory, i)
#             if os.path.exists(file_path):
#                 data_paths.append(directory)
#                 # break
#     return data_paths

# Get all data paths in the dataset
def get_data_paths(data_dir):
    data_paths = []
    for directory in data_dir:
        # Convert filenames to lowercase for easier matching
        # files_lower = [f.lower() for f in files]
        required_files = ['Filtered_R_Image.tif', 'Filtered_T_Image.tif', 'image_data_1.csv']
        if all(f for f in required_files):
            data_paths.append(directory)
    return data_paths

# Normalize and scale x and y to the range 0-605
def transform_coordinates(data):
    # Find the minimum and maximum values of x and y
    x_min, x_max = data['x'].min(), data['x'].max()
    y_min, y_max = data['y'].min(), data['y'].max()

    # Normalize and scale to 0-605
    data['x_new'] = ((data['x'] - x_min) / (x_max - x_min)) * 605
    data['y_new'] = ((data['y'] - y_min) / (y_max - y_min)) * 605
    # # Normalize and scale Sn and Ba
    # data['Sn'] = np.log(data['Sn'] * 1e7  + 1)
    # data['Ba'] = np.log(data['Ba'] * 1e7  + 1)

    return data[['x_new', 'y_new']]

# Collect all categories in the training set
def collect_train_categories(train_paths):
    categories = set()
    for path in train_paths:
        csv_path = os.path.join(path, 'image_data_1.csv')
        if os.path.exists(csv_path):
            data = pd.read_csv(csv_path)
            transformed = transform_coordinates(data)  # Apply coordinate transformation
            data[['x_new', 'y_new']] = transformed
            categories.update(data['target'].unique())
        else:
            print(f"Warning: File not found {csv_path}")
    return sorted(list(categories))

# Get training, validation, and test data paths
train_paths = get_data_paths(train_directories)
val_paths = get_data_paths(val_directories)
test_paths = get_data_paths(test_directories)

# Check if the training set is empty
if not train_paths:
    raise ValueError("No training data found. Please check the training data directory and filenames.")
else:
    print(f"Found {len(train_paths)} training samples.")

if not val_paths:
    print("No validation data found. Please check the validation data directory and filenames.")
else:
    print(f"Found {len(val_paths)} validation samples.")

if not test_paths:
    print("No test data found. Please check the test data directory and filenames.")
else:
    print(f"Found {len(test_paths)} test samples.")

# Collect all categories in the training set
train_categories = collect_train_categories(train_paths)
print(f"Categories in the training set: {train_categories}")
# Out:
# Found 100 training samples.
# Found 50 validation samples.
# Found 50 test samples.
# Categories in the training set: [1, 2, 3]

# %%
import numpy as np
# Fit OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoder.fit(np.array(train_categories).reshape(-1, 1))
num_classes = len(encoder.categories_[0]) + 1  # Add 1 to include background
print(f"Number of classes (including background): {num_classes}")
# Out:
# Number of classes (including background): 4

# %%
from tensorflow.keras.callbacks import Callback, TensorBoard
import math

# %%
# Define data generator for batch loading and preprocessing
class DataGenerator(Sequence):
    def __init__(self, list_IDs, batch_size=1, shuffle=True, encoder=None, num_classes=None):
        """
        Initialize data generator.

        Parameters:
            list_IDs (list): List of data subfolder paths.
            batch_size (int): Number of samples per batch.
            shuffle (bool): Whether to shuffle data after each epoch.
            encoder (OneHotEncoder): Pre-fitted OneHotEncoder.
            num_classes (int): Number of classes (including background).
        """
        self.list_IDs = list_IDs
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.encoder = encoder
        self.num_classes = num_classes
        self.indexes = np.arange(len(self.list_IDs))
        self.on_epoch_end()

    # Return number of steps per epoch
    def __len__(self):
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    # Generate one batch of data
    def __getitem__(self, index):
        # Generate indices of the current batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # Get IDs for the current batch
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        # Generate data
        X, y = self.__data_generation(list_IDs_temp)
        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

    # Generate batch data
    def __data_generation(self, list_IDs_temp):
        # Initialize
        X_batch = []
        y_batch = []
        for ID in list_IDs_temp:
            # Load and preprocess data
            X, y = load_and_preprocess_data(ID, self.encoder, self.num_classes)
            X_batch.append(X)
            y_batch.append(y)
        # Convert to arrays
        X_batch = np.array(X_batch)
        y_batch = np.array(y_batch)
        return X_batch, y_batch

# Load images and label data, and preprocess
def load_and_preprocess_data(data_path, encoder, num_classes, normalize=False):
    image_path_R = os.path.join(data_path, 'Filtered_R_Image.tif')
    image_path_T = os.path.join(data_path, 'Filtered_T_Image.tif')
    csv_path = os.path.join(data_path, 'image_data_1.csv')

    # Load RGB images
    image_R = cv2.imread(image_path_R, cv2.IMREAD_COLOR)
    if image_R is None:
        raise ValueError(f"Cannot read image file: {image_path_R}")
    image_R = cv2.cvtColor(image_R, cv2.COLOR_BGR2RGB)

    image_T = cv2.imread(image_path_T, cv2.IMREAD_COLOR)
    if image_T is None:
        raise ValueError(f"Cannot read image file: {image_path_T}")
    image_T = cv2.cvtColor(image_T, cv2.COLOR_BGR2RGB)

    # Crop both images
    image_R, image_T = combine_data_and_images(image_R, image_T)

    # Load CSV file
    if not os.path.exists(csv_path):
        raise ValueError(f"File not found: {csv_path}")
    data = pd.read_csv(csv_path)

    # Apply coordinate transformation
    transformed = transform_coordinates(data)
    data[['x_new', 'y_new']] = transformed

    # Get image dimensions
    height, width, _ = image_R.shape

    # Extract central circular region
    center_x, center_y = width // 2, height // 2
    radius = 605 // 2

    Y, X_grid = np.ogrid[:height, :width]
    dist_from_center = np.sqrt((X_grid - center_x)**2 + (Y - center_y)**2)
    mask = dist_from_center <= radius

    # Apply mask to each channel
    masked_image_R = np.zeros_like(image_R)
    masked_image_R[mask] = image_R[mask]

    masked_image_T = np.zeros_like(image_T)
    masked_image_T[mask] = image_T[mask]

    # Process numerical variables 'Sn' and 'Ba'
    # Create two single-channel images, initialized to 0
    sn_image = np.zeros((height, width), dtype=np.float32)
    ba_image = np.zeros((height, width), dtype=np.float32)

    # Get data coordinate range
    x_min, x_max = data['x'].min(), data['x'].max()
    y_min, y_max = data['y'].min(), data['y'].max()

    # Map data coordinates to image pixel coordinates
    data['x_pixel'] = data['x_new'].astype(int)
    data['y_pixel'] = data['y_new'].astype(int)
    data['x_pixel'] = data['x_pixel'].clip(0, width - 1)
    data['y_pixel'] = data['y_pixel'].clip(0, height - 1)

    # Fill 'Sn' and 'Ba' images
    for idx, row in data.iterrows():
        x = int(row['x_pixel'])  # Ensure x is integer
        y = int(row['y_pixel'])  # Ensure y is integer
        sn_image[y, x] = row['Sn']
        ba_image[y, x] = row['Ba']

    # # Normalize or standardize 'Sn' and 'Ba'
    # if normalize:
    #     sn_image = (sn_image - np.min(sn_image)) / (np.max(sn_image) - np.min(sn_image) + 1e-7)
    #     sn_image = (sn_image * 255).astype(np.uint8)
    #     ba_image = (ba_image - np.min(ba_image)) / (np.max(ba_image) - np.min(ba_image) + 1e-7)
    #     ba_image = (ba_image * 255).astype(np.uint8)

    # else:
    #     sn_image = (sn_image - np.mean(sn_image)) / (np.std(sn_image) + 1e-7)
    #     ba_image = (ba_image - np.mean(ba_image)) / (np.std(ba_image) + 1e-7)

    # Apply mask to 'Sn' and 'Ba' images
    masked_sn = np.zeros_like(sn_image)
    masked_sn[mask] = sn_image[mask]

    masked_ba = np.zeros_like(ba_image)
    masked_ba[mask] = ba_image[mask]

    # Normalize 'Sn' and 'Ba' images to [0, 255]
    max_sn = np.max(masked_sn)
    max_ba = np.max(masked_ba)
    masked_sn = (masked_sn / max_sn * 255).astype(np.uint8) if max_sn != 0 else masked_sn.astype(np.uint8)
    masked_ba = (masked_ba / max_ba * 255).astype(np.uint8) if max_ba != 0 else masked_ba.astype(np.uint8)

    # Adjust image size to multiples of 16
    new_height = (height // 16) * 16
    new_width = (width // 16) * 16
    masked_image_R = masked_image_R[:new_height, :new_width, :]
    masked_image_T = masked_image_T[:new_height, :new_width, :]
    masked_sn = masked_sn[:new_height, :new_width]
    masked_ba = masked_ba[:new_height, :new_width]
    height, width, _ = masked_image_R.shape

    # Add 'Sn' and 'Ba' as additional channels
    sn_channel = np.expand_dims(masked_sn, axis=-1)
    ba_channel = np.expand_dims(masked_ba, axis=-1)
    input_image = np.concatenate([masked_image_R, masked_image_T, sn_channel, ba_channel], axis=-1)

    # Encode the 'Category' column
    categories_encoded = encoder.transform(data[['target']])

    # Create target mask
    target_mask = np.zeros((height, width), dtype=np.uint8)

    for idx, row in data.iterrows():
        x = int(row['x_pixel'])  # Ensure x is integer
        y = int(row['y_pixel'])  # Ensure y is integer
        category_index = int(np.argmax(categories_encoded[idx]) + 1)  # Add 1 to avoid background being 0
        cv2.circle(target_mask, (x, y), point_radius, category_index, -1)

    # One-Hot encode the target mask
    target_mask_one_hot = to_categorical(target_mask, num_classes=num_classes)

    return input_image, target_mask_one_hot

# Create training, validation, and test data generators
train_generator = DataGenerator(train_paths, batch_size=1, shuffle=True, encoder=encoder, num_classes=num_classes)
val_generator = DataGenerator(val_paths, batch_size=1, shuffle=False, encoder=encoder, num_classes=num_classes)
test_generator = DataGenerator(test_paths, batch_size=1, shuffle=False, encoder=encoder, num_classes=num_classes)

# %%
# Define UNet model
def unet_model(input_size, num_classes):
    inputs = layers.Input(input_size)

    # Downsampling part
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(inputs)
    # c1 = layers.SpatialDropout2D(0.1)(c1)  # Add dropout
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2,2), padding='same')(c1)

    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(p1)
    # c2 = layers.Dropout(0.1)(c2)  # Add dropout
    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2,2), padding='same')(c2)

    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(p2)
    # c3 = layers.Dropout(0.2)(c3)  # Add dropout
    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2,2), padding='same')(c3)

    c4 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(p3)
    # c4 = layers.Dropout(0.2)(c4)  # Add dropout
    c4 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D((2,2), padding='same')(c4)

    # Bottleneck
    c5 = layers.Conv2D(1024, (3,3), activation='relu', padding='same')(p4)
    # c5 = layers.Dropout(0.3)(c5)
    c5 = layers.Conv2D(1024, (3,3), activation='relu', padding='same')(c5)

    # Upsampling part
    u6 = layers.UpSampling2D((2,2))(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(u6)
    # c6 = layers.Dropout(0.2)(c6)
    c6 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(c6)

    u7 = layers.UpSampling2D((2,2))(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(u7)
    # c7 = layers.Dropout(0.2)(c7)
    c7 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c7)

    u8 = layers.UpSampling2D((2,2))(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(u8)
    # c8 = layers.Dropout(0.1)(c8)
    c8 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c8)

    u9 = layers.UpSampling2D((2,2))(c8)
    u9 = layers.concatenate([u9, c1])
    c9 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(u9)
    # c9 = layers.SpatialDropout2D(0.1)(c9)
    c9 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c9)

    outputs = layers.Conv2D(num_classes, (1,1), activation='softmax')(c9)

    model = models.Model(inputs=[inputs], outputs=[outputs])
    return model

# Create model
sample_X, sample_y = train_generator[0]
input_height, input_width, _ = sample_X.shape[1:]
input_size = (input_height, input_width, input_channels)

model = unet_model(input_size=input_size, num_classes=num_classes)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define learning rate scheduler
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Monitor validation loss
    factor=0.5,            # When the monitored metric stops improving, reduce learning rate by half
    patience=3,            # Number of epochs with no improvement before reducing learning rate
    min_lr=1e-5          # Minimum learning rate
)

# Add callbacks when training the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=60,
    callbacks=[reduce_lr]
)

model.save('unet_model1.h5')
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 592, 592, 8)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 592, 592, 64)   │          4,672 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 592, 592, 64)   │         36,928 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 296, 296, 64)   │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 296, 296, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 296, 296, 128)  │        147,584 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 148, 148, 128)  │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 148, 148, 256)  │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 148, 148, 256)  │        590,080 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 74, 74, 256)    │              0 │ conv2d_5[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 74, 74, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 74, 74, 512)    │      2,359,808 │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 37, 37, 512)    │              0 │ conv2d_7[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 37, 37, 1024)   │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 37, 37, 1024)   │      9,438,208 │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d             │ (None, 74, 74, 1024)   │              0 │ conv2d_9[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 74, 74, 1536)   │              0 │ up_sampling2d[0][0],   │
# │                           │                        │                │ conv2d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 74, 74, 512)    │      7,078,400 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 74, 74, 512)    │      2,359,808 │ conv2d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_1           │ (None, 148, 148, 512)  │              0 │ conv2d_11[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 148, 148, 768)  │              0 │ up_sampling2d_1[0][0], │
# │ (Concatenate)             │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 148, 148, 256)  │      1,769,728 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 148, 148, 256)  │        590,080 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_2           │ (None, 296, 296, 256)  │              0 │ conv2d_13[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 296, 296, 384)  │              0 │ up_sampling2d_2[0][0], │
# │ (Concatenate)             │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 296, 296, 128)  │        442,496 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 296, 296, 128)  │        147,584 │ conv2d_14[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_3           │ (None, 592, 592, 128)  │              0 │ conv2d_15[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 592, 592, 192)  │              0 │ up_sampling2d_3[0][0], │
# │ (Concatenate)             │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 592, 592, 64)   │        110,656 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 592, 592, 64)   │         36,928 │ conv2d_16[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 592, 592, 4)    │            260 │ conv2d_17[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,382,020 (119.71 MB)
#  Trainable params: 31,382,020 (119.71 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 343s 3s/step - accuracy: 0.5362 - loss: 23.4940 - val_accuracy: 0.7097 - val_loss: 0.6137 - learning_rate: 0.0010
# Epoch 2/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.6399 - loss: 0.9843 - val_accuracy: 0.6866 - val_loss: 0.6995 - learning_rate: 0.0010
# Epoch 3/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.6682 - loss: 0.6482 - val_accuracy: 0.6579 - val_loss: 0.7237 - learning_rate: 0.0010
# Epoch 4/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.6959 - loss: 0.6355 - val_accuracy: 0.6960 - val_loss: 0.6285 - learning_rate: 0.0010
# Epoch 5/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.6931 - loss: 0.6284 - val_accuracy: 0.7095 - val_loss: 0.5955 - learning_rate: 5.0000e-04
# Epoch 6/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.6851 - loss: 0.6344 - val_accuracy: 0.7257 - val_loss: 0.5663 - learning_rate: 5.0000e-04
# Epoch 7/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.7041 - loss: 0.5920 - val_accuracy: 0.7169 - val_loss: 0.6016 - learning_rate: 5.0000e-04
# Epoch 8/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.7283 - loss: 0.5632 - val_accuracy: 0.7389 - val_loss: 0.5779 - learning_rate: 5.0000e-04
# Epoch 9/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.7351 - loss: 0.5551 - val_accuracy: 0.6669 - val_loss: 0.6145 - learning_rate: 5.0000e-04
# Epoch 10/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.7526 - loss: 0.5289 - val_accuracy: 0.7576 - val_loss: 0.5215 - learning_rate: 2.5000e-04
# Epoch 11/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7471 - loss: 0.5345 - val_accuracy: 0.7538 - val_loss: 0.5328 - learning_rate: 2.5000e-04
# Epoch 12/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7512 - loss: 0.5305 - val_accuracy: 0.7577 - val_loss: 0.5304 - learning_rate: 2.5000e-04
# Epoch 13/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.7462 - loss: 0.5318 - val_accuracy: 0.7800 - val_loss: 0.4828 - learning_rate: 2.5000e-04
# Epoch 14/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.7584 - loss: 0.5189 - val_accuracy: 0.7804 - val_loss: 0.4770 - learning_rate: 2.5000e-04
# Epoch 15/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.7864 - loss: 0.4619 - val_accuracy: 0.7928 - val_loss: 0.4626 - learning_rate: 2.5000e-04
# Epoch 16/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.7787 - loss: 0.4728 - val_accuracy: 0.7315 - val_loss: 0.5175 - learning_rate: 2.5000e-04
# Epoch 17/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1000ms/step - accuracy: 0.7711 - loss: 0.4688 - val_accuracy: 0.8012 - val_loss: 0.4583 - learning_rate: 2.5000e-04
# Epoch 18/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.7931 - loss: 0.4412 - val_accuracy: 0.8100 - val_loss: 0.4293 - learning_rate: 2.5000e-04
# Epoch 19/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7760 - loss: 0.4936 - val_accuracy: 0.8067 - val_loss: 0.4383 - learning_rate: 2.5000e-04
# Epoch 20/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7907 - loss: 0.4514 - val_accuracy: 0.7470 - val_loss: 0.5347 - learning_rate: 2.5000e-04
# Epoch 21/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7777 - loss: 0.4752 - val_accuracy: 0.8166 - val_loss: 0.4213 - learning_rate: 2.5000e-04
# Epoch 22/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.8064 - loss: 0.4365 - val_accuracy: 0.8205 - val_loss: 0.4259 - learning_rate: 2.5000e-04
# Epoch 23/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.8197 - loss: 0.4100 - val_accuracy: 0.7988 - val_loss: 0.4782 - learning_rate: 2.5000e-04
# Epoch 24/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7774 - loss: 0.4881 - val_accuracy: 0.8304 - val_loss: 0.3990 - learning_rate: 2.5000e-04
# Epoch 25/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7820 - loss: 0.4541 - val_accuracy: 0.8015 - val_loss: 0.4462 - learning_rate: 2.5000e-04
# Epoch 26/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8111 - loss: 0.4108 - val_accuracy: 0.8147 - val_loss: 0.4198 - learning_rate: 2.5000e-04
# Epoch 27/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8100 - loss: 0.4306 - val_accuracy: 0.8060 - val_loss: 0.4248 - learning_rate: 2.5000e-04
# Epoch 28/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8309 - loss: 0.3728 - val_accuracy: 0.8206 - val_loss: 0.4143 - learning_rate: 1.2500e-04
# Epoch 29/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8246 - loss: 0.3838 - val_accuracy: 0.8445 - val_loss: 0.3636 - learning_rate: 1.2500e-04
# Epoch 30/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8297 - loss: 0.3670 - val_accuracy: 0.8297 - val_loss: 0.3876 - learning_rate: 1.2500e-04
# Epoch 31/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8253 - loss: 0.3897 - val_accuracy: 0.8128 - val_loss: 0.3983 - learning_rate: 1.2500e-04
# Epoch 32/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8567 - loss: 0.3209 - val_accuracy: 0.8614 - val_loss: 0.3140 - learning_rate: 1.2500e-04
# Epoch 33/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8680 - loss: 0.2934 - val_accuracy: 0.8763 - val_loss: 0.2776 - learning_rate: 1.2500e-04
# Epoch 34/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8733 - loss: 0.2762 - val_accuracy: 0.8502 - val_loss: 0.3058 - learning_rate: 1.2500e-04
# Epoch 35/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8774 - loss: 0.2731 - val_accuracy: 0.8745 - val_loss: 0.2675 - learning_rate: 1.2500e-04
# Epoch 36/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8709 - loss: 0.2849 - val_accuracy: 0.8755 - val_loss: 0.2925 - learning_rate: 1.2500e-04
# Epoch 37/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8731 - loss: 0.2744 - val_accuracy: 0.8889 - val_loss: 0.2568 - learning_rate: 1.2500e-04
# Epoch 38/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8921 - loss: 0.2517 - val_accuracy: 0.8304 - val_loss: 0.3400 - learning_rate: 1.2500e-04
# Epoch 39/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8844 - loss: 0.2473 - val_accuracy: 0.8883 - val_loss: 0.2495 - learning_rate: 1.2500e-04
# Epoch 40/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8860 - loss: 0.2503 - val_accuracy: 0.8929 - val_loss: 0.2376 - learning_rate: 1.2500e-04
# Epoch 41/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8891 - loss: 0.2387 - val_accuracy: 0.8995 - val_loss: 0.2315 - learning_rate: 1.2500e-04
# Epoch 42/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8919 - loss: 0.2268 - val_accuracy: 0.9056 - val_loss: 0.2264 - learning_rate: 1.2500e-04
# Epoch 43/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9004 - loss: 0.2218 - val_accuracy: 0.8944 - val_loss: 0.2297 - learning_rate: 1.2500e-04
# Epoch 44/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9049 - loss: 0.2174 - val_accuracy: 0.8943 - val_loss: 0.2479 - learning_rate: 1.2500e-04
# Epoch 45/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9006 - loss: 0.2205 - val_accuracy: 0.8576 - val_loss: 0.2934 - learning_rate: 1.2500e-04
# Epoch 46/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.8927 - loss: 0.2318 - val_accuracy: 0.9103 - val_loss: 0.2102 - learning_rate: 6.2500e-05
# Epoch 47/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9155 - loss: 0.1967 - val_accuracy: 0.9175 - val_loss: 0.1934 - learning_rate: 6.2500e-05
# Epoch 48/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9133 - loss: 0.1940 - val_accuracy: 0.9025 - val_loss: 0.2225 - learning_rate: 6.2500e-05
# Epoch 49/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9150 - loss: 0.1845 - val_accuracy: 0.9332 - val_loss: 0.1630 - learning_rate: 6.2500e-05
# Epoch 50/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9170 - loss: 0.1886 - val_accuracy: 0.9456 - val_loss: 0.1371 - learning_rate: 6.2500e-05
# Epoch 51/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.9364 - loss: 0.1445 - val_accuracy: 0.9478 - val_loss: 0.1315 - learning_rate: 6.2500e-05
# Epoch 52/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9354 - loss: 0.1465 - val_accuracy: 0.9538 - val_loss: 0.1198 - learning_rate: 6.2500e-05
# Epoch 53/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.9592 - loss: 0.1015 - val_accuracy: 0.9644 - val_loss: 0.0915 - learning_rate: 6.2500e-05
# Epoch 54/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.9636 - loss: 0.0900 - val_accuracy: 0.9678 - val_loss: 0.0810 - learning_rate: 6.2500e-05
# Epoch 55/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.9612 - loss: 0.0913 - val_accuracy: 0.9715 - val_loss: 0.0740 - learning_rate: 6.2500e-05
# Epoch 56/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.9605 - loss: 0.0923 - val_accuracy: 0.9703 - val_loss: 0.0760 - learning_rate: 6.2500e-05
# Epoch 57/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.9663 - loss: 0.0805 - val_accuracy: 0.9728 - val_loss: 0.0701 - learning_rate: 6.2500e-05
# Epoch 58/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9673 - loss: 0.0775 - val_accuracy: 0.9708 - val_loss: 0.0772 - learning_rate: 6.2500e-05
# Epoch 59/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9642 - loss: 0.0858 - val_accuracy: 0.9735 - val_loss: 0.0681 - learning_rate: 6.2500e-05
# Epoch 60/60
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.9684 - loss: 0.0735 - val_accuracy: 0.9710 - val_loss: 0.0731 - learning_rate: 6.2500e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save('my_model.keras')

# %%
from keras.saving import load_model
model1 = load_model('unet_model_100_50_50.h5')

import matplotlib.pyplot as plt
import numpy as np

# Evaluate the model on the test set and calculate accuracy
test_loss, test_acc = model1.evaluate(test_generator)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_acc}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.9702 - loss: 0.0753
# Test Loss: 0.07778474688529968, Test Accuracy: 0.9685348272323608

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # # Evaluate the model on the test set and calculate accuracy
# # test_loss, test_acc = model.evaluate(test_generator)
# # print(f'Test Loss: {test_loss}, Test Accuracy: {test_acc}')

# # Visualize results on the test set
# def visualize_predictions(generator, model, num_samples=10):
#     """
#     Visualize model predictions on the test set.

#     Parameters:
#         generator (DataGenerator): Test set data generator.
#         model (tf.keras.Model): Trained model.
#         num_samples (int): Number of samples to visualize.
#     """
#     for i in range(num_samples):
#         X, y_true = generator[i]
#         y_pred = model.predict(X)

#         # Get the input image, prediction, and true labels for a single sample
#         input_image = X[0]  # Input image
#         y_true = np.argmax(y_true[0], axis=-1)  # True labels
#         y_pred = np.argmax(y_pred[0], axis=-1)  # Predicted labels

#         # Visualize the results
#         fig, axes = plt.subplots(1, 3, figsize=(15, 5))
#         axes[0].imshow(input_image[..., :3].astype(int))  # Show the first RGB image
#         axes[0].set_title("Input Image (R)")
#         axes[0].axis('off')

#         axes[1].imshow(y_true, cmap="jet")  # True labels
#         axes[1].set_title("True Labels")
#         axes[1].axis('off')

#         axes[2].imshow(y_pred, cmap="jet")  # Predicted labels
#         axes[2].set_title("Predicted Labels")
#         axes[2].axis('off')

#         plt.show()

# # Visualize some predictions on the test set
# visualize_predictions(test_generator, model1, num_samples=5)

# %%
# # Visualize some predictions on the test set
# visualize_predictions(test_generator, model1, num_samples=10)

# %%
# random.shuffle(test_directories)
test_directories
# Out:
# ['/content/drive/My Drive/Random_series/Random_series_165',
#  '/content/drive/My Drive/Random_series/Random_series_189',
#  '/content/drive/My Drive/Random_series/Random_series_033',
#  '/content/drive/My Drive/Random_series/Random_series_119',
#  '/content/drive/My Drive/Random_series/Random_series_005',
#  '/content/drive/My Drive/Random_series/Random_series_097',
#  '/content/drive/My Drive/Random_series/Random_series_083',
#  '/content/drive/My Drive/Random_series/Random_series_008',
#  '/content/drive/My Drive/Random_series/Random_series_041',
#  '/content/drive/My Drive/Random_series/Random_series_135',
#  '/content/drive/My Drive/Random_series/Random_series_098',
#  '/content/drive/My Drive/Random_series/Random_series_016',
#  '/content/drive/My Drive/Random_series/Random_series_057',
#  '/content/drive/My Drive/Random_series/Random_series_050',
#  '/content/drive/My Drive/Random_series/Random_series_198',
#  '/content/drive/My Drive/Random_series/Random_series_138',
#  '/content/drive/My Drive/Random_series/Random_series_153',
#  '/content/drive/My Drive/Random_series/Random_series_171',
#  '/content/drive/My Drive/Random_series/Random_series_120',
#  '/content/drive/My Drive/Random_series/Random_series_078',
#  '/content/drive/My Drive/Random_series/Random_series_130',
#  '/content/drive/My Drive/Random_series/Random_series_104',
#  '/content/drive/My Drive/Random_series/Random_series_091',
#  '/content/drive/My Drive/Random_series/Random_series_186',
#  '/content/drive/My Drive/Random_series/Random_series_139',
#  '/content/drive/My Drive/Random_series/Random_series_076',
#  '/content/drive/My Drive/Random_series/Random_series_082',
#  '/content/drive/My Drive/Random_series/Random_series_193',
#  '/content/drive/My Drive/Random_series/Random_series_004',
#  '/content/drive/My Drive/Random_series/Random_series_148',
#  '/content/drive/My Drive/Random_series/Random_series_170',
#  '/content/drive/My Drive/Random_series/Random_series_145',
#  '/content/drive/My Drive/Random_series/Random_series_126',
#  '/content/drive/My Drive/Random_series/Random_series_036',
#  '/content/drive/My Drive/Random_series/Random_series_052',
#  '/content/drive/My Drive/Random_series/Random_series_013',
#  '/content/drive/My Drive/Random_series/Random_series_058',
#  '/content/drive/My Drive/Random_series/Random_series_167',
#  '/content/drive/My Drive/Random_series/Random_series_105',
#  '/content/drive/My Drive/Random_series/Random_series_166',
#  '/content/drive/My Drive/Random_series/Random_series_118',
#  '/content/drive/My Drive/Random_series/Random_series_046',
#  '/content/drive/My Drive/Random_series/Random_series_159',
#  '/content/drive/My Drive/Random_series/Random_series_067',
#  '/content/drive/My Drive/Random_series/Random_series_121',
#  '/content/drive/My Drive/Random_series/Random_series_183',
#  '/content/drive/My Drive/Random_series/Random_series_053',
#  '/content/drive/My Drive/Random_series/Random_series_002',
#  '/content/drive/My Drive/Random_series/Random_series_070',
#  '/content/drive/My Drive/Random_series/Random_series_191']

# %%
data_arr = []
count = 0
for directory in test_directories:
    file_path = os.path.join(directory, 'image_data_1.csv')
    print(file_path)
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        data_arr.append(df)
        count += 1
        if count == 8:
          break



# print(file_path)
len(data_arr)
# Out:
# /content/drive/My Drive/Random_series/Random_series_165/image_data_1.csv
# /content/drive/My Drive/Random_series/Random_series_189/image_data_1.csv
# /content/drive/My Drive/Random_series/Random_series_033/image_data_1.csv
# /content/drive/My Drive/Random_series/Random_series_119/image_data_1.csv
# /content/drive/My Drive/Random_series/Random_series_005/image_data_1.csv
# /content/drive/My Drive/Random_series/Random_series_097/image_data_1.csv
# /content/drive/My Drive/Random_series/Random_series_083/image_data_1.csv
# /content/drive/My Drive/Random_series/Random_series_008/image_data_1.csv
# 8

# %%
# from keras.saving import load_model
# model1 = load_model('unet_model1.h5')

# %%
len(test_generator)
# Out:
# 50

# %%
len(data_arr)
# Out:
# 8

# %%
# from sklearn.gaussian_process import GaussianProcessRegressor
# from sklearn.gaussian_process.kernels import RBF

# df = pd.DataFrame(data_arr[0])

# # Normalize F to [0, 1]
# df['F_normalized'] = (df['F'] - df['F'].min()) / (df['F'].max() - df['F'].min())

# # Interpolate NaNs using pandas' interpolate method
# df['F_normalized'] = df['F_normalized'].interpolate(method='linear')

# # Create grid for contouring
# xi = np.linspace(df['x'].min(), df['x'].max(), 500)
# yi = np.linspace(df['y'].min(), df['y'].max(), 500)
# Xi, Yi = np.meshgrid(xi, yi)

# # Interpolate F onto the grid
# F_grid = griddata((df['x'], df['y']), df['F_normalized'], (Xi, Yi), method='linear')# Plot the contour directly
# plt.contour(Xi, Yi, F_grid, levels=10)
# # Ensure equal aspect ratio (aspect ratio of 1:1 between x and y)
# plt.gca().set_aspect('equal', adjustable='box')
# plt.colorbar(label="Normalized F")
# plt.show()

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from sklearn.gaussian_process import GaussianProcessRegressor
# from sklearn.gaussian_process.kernels import RBF
# from scipy.interpolate import griddata

# # Assuming data_arr is already defined
# df = pd.DataFrame(data_arr[0])

# # Normalize F to [0, 1]
# df['F_normalized'] = (df['F'] - df['F'].min()) / (df['F'].max() - df['F'].min())

# # Interpolate NaNs using pandas' interpolate method
# df['F_normalized'] = df['F_normalized'].interpolate(method='linear')

# # Prepare data for Gaussian Process (X should contain both 'x' and 'y' columns)
# X = df[['x', 'y']].values
# y = df['F_normalized'].values

# # Fit Gaussian Process model
# kernel = RBF(length_scale=1.0)  # Adjust the length scale based on your data
# gp = GaussianProcessRegressor(kernel=kernel)
# gp.fit(X, y)

# # Create grid for contouring
# xi = np.linspace(df['x'].min(), df['x'].max(), 500)
# yi = np.linspace(df['y'].min(), df['y'].max(), 500)
# Xi, Yi = np.meshgrid(xi, yi)

# # Predict values on the grid using the Gaussian Process model
# grid_points = np.column_stack((Xi.ravel(), Yi.ravel()))
# F_gp = gp.predict(grid_points).reshape(Xi.shape)

# # Plot the contour with Gaussian Process model
# plt.contour(Xi, Yi, F_gp, levels=10)

# # Ensure equal aspect ratio (aspect ratio of 1:1 between x and y)
# plt.gca().set_aspect('equal', adjustable='box')

# # Add color bar for reference
# plt.colorbar(label="Smoothed F")
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata
from scipy.ndimage import gaussian_filter

# Function to visualize predictions with contours
def visualize_combined_predictions_with_contours(generator, model, data_arr, num_samples=5):
    """
    Combine the predicted labels with contours of F into a single visualization.

    Parameters:
        generator (DataGenerator): Test set data generator.
        model (tf.keras.Model): Trained model.
        F_grid (np.array): Interpolated F values on a grid.
        Xi, Yi (np.array): Meshgrid for x and y coordinates.
        num_samples (int): Number of samples to visualize.
    """
    for i in range(num_samples):
        data = data_arr[i]

        # Assuming `data` is already loaded for contouring
        x = data['x']
        y = -data['y']
        F = data['F']

        # Create a grid for the F contour
        xi = np.linspace(x.min(), x.max(), 500)
        yi = np.linspace(y.min(), y.max(), 500)
        Xi, Yi = np.meshgrid(xi, yi)

        # Interpolating F onto the grid
        F_grid = griddata((x, y), F, (Xi, Yi), method='linear')
        print(F_grid.shape)
        # F_grid = np.nan_to_num(F_grid, nan=0)

        # # Apply rotation based on specific ranges of Xi
        # # Define the rotation angles for different ranges
        # angles = {
        #     'no_rotation': (np.radians(0), (-2.5, -0.9)),
        #     'rotate_minus3': (np.radians(-4), (-0.9, 1.1)),
        #     'rotate_minus7': (np.radians(-7), (1.11, 2.5)),
        # }

        # # Apply the rotations to different ranges
        # rotated_Xi = np.copy(Xi)
        # rotated_Yi = np.copy(Yi)

        # for rotation_type, (theta, (min_xi, max_xi)) in angles.items():
        #     # Create a mask for the current range
        #     mask = (Xi >= min_xi) & (Xi <= max_xi)

        #     # Apply the rotation only to the selected region
        #     rotation_matrix = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]])

        #     rotated_Xi[mask] = np.dot(rotation_matrix, np.vstack([Xi[mask].ravel(), Yi[mask].ravel()]))[0].reshape(Xi[mask].shape)
        #     rotated_Yi[mask] = np.dot(rotation_matrix, np.vstack([Xi[mask].ravel(), Yi[mask].ravel()]))[1].reshape(Yi[mask].shape)
        # Re-interpolate F values onto the rotated grid
        # F_grid_rotated = griddata((x, y), F, (Xi, Yi), method='linear')
        # Load a batch from the generator
        X, y_true = generator[i]
        y_pred = model.predict(X)

        # Get the input image, true labels, and predicted labels for a single sample
        input_image = X[0]  # Input image
        y_true = np.argmax(y_true[0], axis=-1)  # True labels
        y_pred = np.argmax(y_pred[0], axis=-1)  # Predicted labels

        # # identify where y_true and y_pred match between the two regions
        # matching_points_true = []
        # matching_points_pred = []

        # for j in range(Xi.shape[0]):  # Iterate over the grid
        #     for k in range(Xi.shape[1]):
        #         if y_true[j, k] != y_pred[j, k]:
        #             matching_points_true.append([Xi[j, k], Yi[j, k]])
        #             matching_points_pred.append([Xi[j, k], Yi[j, k]])

        # matching_points_true = np.array(matching_points_true)
        # matching_points_pred = np.array(matching_points_pred)

        # Plot the results
        fig, axes = plt.subplots(1, 3, figsize=(18, 5))

        # Input image
        axes[0].imshow(input_image[..., :3].astype(int))  # Show the first RGB image
        axes[0].set_title("Input Image (R)")
        axes[0].axis('off')

        # True labels with contours
        axes[1].imshow(y_true, extent=[-2.5, 2.5, -2.5, 2.5], cmap="jet", interpolation="nearest", alpha=0.9)  # True labels
        contour1 = axes[1].contour(Xi, Yi, F_grid, levels=20, colors='black', linewidths=1.2)  # Contours
        axes[1].clabel(contour1, inline=True, fontsize=8, fmt="%.2f")
        axes[1].set_title("True Labels + Contours")
        # axes[1].axis('off')

        # Predicted labels with contours (combined image)
        axes[2].imshow(y_pred, extent=[-2.5, 2.5, -2.5, 2.5], cmap="jet", interpolation="nearest", alpha=0.9)  # Predicted labels
        contour2 = axes[2].contour(Xi, Yi, F_grid, levels=20, colors='black', linewidths=1.2)  # Contours
        axes[2].clabel(contour2, inline=True, fontsize=8, fmt="%.2f")
        axes[2].set_title("Predicted Labels + Contours (Combined)")
        # axes[2].axis('off')

        # Plot lines where y_true and y_pred match
        # axes[2].plot(matching_points_true[:, 0], matching_points_true[:, 1], 'go', markersize=1, label='Matching Points (True)')
        # axes[2].plot(matching_points_pred[:, 0], matching_points_pred[:, 1], 'g-', linewidth=2,  label='Matching Points (Pred)')
        # for true_point, pred_point in zip(matching_points_true, matching_points_pred):
        #   axes[2].plot([true_point[0], true_point[0]], [true_point[1], pred_point[1]], 'g-', linewidth=1.5)


        # Adjust layout and show the plot
        plt.tight_layout()
        plt.show()
# Call the function to visualize
visualize_combined_predictions_with_contours(test_generator, model1, data_arr, num_samples=8)
# Out:
# (500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 769ms/step
# (500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# (500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# (500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# (500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# (500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# (500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# (500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %% [markdown]
# # Testing ( debugging )

# %%
        # # Display the colormap
        # plt.imshow(y_pred, extent=[-2.5, 2.5, -2.5, 2.5], cmap="viridis", origin='lower', alpha=0.9)  # Predicted labels with colormap

        # # Overlay the contours
        # contour = plt.contour(Xi, Yi, F_grid, levels=20, colors='black', linewidths=1.5)  # Thicker contours
        # plt.clabel(contour, inline=True, fontsize=10, fmt="%.2f")  # Add contour labels

        # # Titles and axes adjustments
        # plt.title("Colormap with Contours")
        # # plt.axis('off')

        # # Add a colorbar
        # # fig.colorbar(im, ax=ax, shrink=0.8, label="Predicted Labels")

        # plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random data for the colormap
np.random.seed(42)  # For reproducibility
data = np.random.rand(100, 100)  # 2D array of random values

# Generate random lines
num_lines = 10
x = np.linspace(0, 99, 100)  # X-axis coordinates
lines = [np.sin(x / 10 + i) * 10 + 50 for i in range(num_lines)]  # Sine waves with offsets

# Plot the colormap
plt.figure(figsize=(8, 6))
plt.imshow(data, cmap='jet', origin='lower', aspect='auto')
plt.colorbar(label='Intensity')

# Overlay the lines
for line in lines:
    plt.plot(x, line, color='white', linewidth=1.5, alpha=0.8)

# Label and show the plot
plt.title("Colormap with Overlayed Lines")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have colormap data and contour levels
# Replace with your actual data
x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X**2 + Y**2)

# Colormap
plt.imshow(Z, extent=[-1, 1, -1, 1], origin='lower', cmap='viridis', alpha=0.9)

# Contours
contour_levels = np.linspace(Z.min(), Z.max(), 10)
contours = plt.contour(X, Y, Z, levels=contour_levels, colors='black', linewidths=1)

# Add labels to contours
plt.clabel(contours, inline=True, fontsize=8)

# Show combined plot
plt.colorbar()
plt.title("Colormap with Contours")
plt.show()

# %%
# y_test.shape

# %%
# X_test[40176:40200], y_test[40176:40200], y_test_pred[40176:40200]

# %%
import cv2

# %%
def get_image_data(image_index, test_data):
    start_row = image_index * 8092
    end_row = start_row + 8092
    return test_data.iloc[start_row:end_row]

# Example: Get data for the first image (image_index = 0)
first_image_data = get_image_data(0, test_data)
print(first_image_data.shape)
first_image_data.head()

# %%
first_image_data.describe()
